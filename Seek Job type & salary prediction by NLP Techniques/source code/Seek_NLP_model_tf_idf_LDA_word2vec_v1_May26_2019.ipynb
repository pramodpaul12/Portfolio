# %% [markdown]
# # NLP models:  Tfidf, LDA & Word2vec are tested

# %%
import requests
from scrapy.selector import Selector
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np

# %%
Job = pd.read_csv('R_JobDF_Final_to_edited.csv', sep =',')

# %%
Job.head()
# Out:
#    Unnamed: 0                                            Job_url  \
# 0           0  https://www.seek.com.au/job/39063945?type=stan...
# 1           1  https://www.seek.com.au/job/39044001?type=stan...
# 2           2  https://www.seek.com.au/job/39045995?type=stan...
# 3           3  https://www.seek.com.au/job/39033202?type=stan...
# 4           4  https://www.seek.com.au/job/39064335?type=stan...
#
#                                         Company_name  \
# 0  Talent – Winner ‘Seek Large Recruitment Ag...
# 1                             Premium IT Recruitment
# 2                                Ambition Technology
# 3                             Hydrogen Group Pty Ltd
# 4                                                NAB
#
#                                            Job_title Job_date  Contract1  \
# 0                                       Data Analyst      NaN        NaN
# 1  Data Conversion Analyst - Excel, VBA, SQL - $6...      NaN        NaN
# ...

# %%
Job.columns
# Out:
# Index(['Unnamed: 0', 'Job_url', 'Company_name', 'Job_title', 'Job_date',
#        'Contract1', 'Salary', 'Description', 'Job_no'],
#       dtype='object')

# %%
Job.drop(columns ='Unnamed: 0', axis = 1, inplace = True)

# %%
Job.head(20);

# %%
Job_title_list = Job['Job_title'].values

# %%
Job_title_list
# Out:
# array(['Data Analyst',
#        'Data Conversion Analyst - Excel, VBA, SQL - $60k plus super, career growth',
#        'Data Visualisation Analyst', 'Data Analyst',
#        'NAB Technology Internship Program – Data Analyst',
#        'Data Designer / Data Analyst', 'Commercial Data Analyst',
#        'Data Analyst Contracts Administrator',
#        'Japanese-speaking Junior Data Analyst',
#        'Data Analyst - Asset Management Project (Immediate Start Contract Role)',
#        'Data Analyst Contracts Administrator',
#        'Business Analyst - Big Data', 'Data Analyst',
#        'Data Analyst (M37)', 'Data Analyst', 'Data Analyst',
#        'Data Analyst- MySQL', 'no title',
#        'Data Governance Business Analyst', 'Data Analyst', 'no title',
#        'BI Analyst - Tableau', 'Senior Data Analyst',
#        'Data Analyst - Credit',
#        'Technical Business Analyst - Legacy Data Project - Health',
#        'Data Analyst / Game Analyst', 'no title',
# ...

# %%
Job.Job_title.replace(np.nan, 'no title',inplace = True)

# %%
#job_t = Job['Job_title']

#for it in job_t:
#    print(type(str(it)))

# %%
import re  
import nltk

# %%
restring = 'Data Conversion analyst - Excel, VBA, SQL - $6'
restring =  restring.lower()
test = re.findall('analyst',restring )
test
# Out:
# ['analyst']

# %%
x='wer'
x = type(x)
x
# Out:
# str

# %%
title_string = 'data  mid level'

# %%
def job_title_map(title_string):
    title_string =  title_string.lower()
    clean_analyst = re.findall('analyst',title_string)
    clean_scientist = re.findall('scientist',title_string)
    clean_manager = re.findall('manager',title_string)
    
    if clean_analyst == ['analyst']:    
            return('Data Analyst')
    elif clean_scientist == ['scientist']:  
            return('Data Scientist')
    elif clean_manager == ['manager']:
            return('Data manager')
    else:                
            print('no info')

# %%
job_title_map(title_string)
# Out:
# no info

# %%
Entry_level_string = 'entry, trainee ,intern,graduate'
level_string = 'trainee level'
clean_Trainee = re.findall(Entry_level_string,level_string)
clean_Trainee
# Out:
# []

# %%
Entry_level_list = ['entry','trainee','intern','graduate']
Junior_level_list = ['junior']
Mid_level_list = ['mid']
Senior_level_list = ['senior','lead']
Manager_level_list = ['Manager','manager']


def job_level_map(level_string):
    level_string =  level_string.lower()
    clean_Trainee = re.findall('trainee',level_string)
    clean_intern = re.findall('intern',level_string) 
    clean_graduate = re.findall('graduate',level_string)
    clean_entry = re.findall('entry',level_string)                                     
    clean_Junior = re.findall('junior',level_string)
    clean_mid = re.findall('mid',level_string)
    clean_senior = re.findall('senior',level_string)
    clean_lead = re.findall('lead',level_string)
    clean_manager = re.findall('manager',level_string)
        
    if ((clean_Trainee == ['trainee']) or   (clean_intern ==  ['intern']) or (clean_graduate ==  ['graduate'])
        or (clean_entry == ['entry'])):        
            return('Trainee')
    elif clean_Junior == ['junior']:  
            return('Junior')
    elif clean_mid == ['mid']:  
            return('mid')   
    elif clean_senior == ['senior']:  
            return('senior')         
    elif clean_lead == ['lead']:  
            return('lead')              
    elif clean_manager == ['manager']:
            return('manager')
    else:                
            print('no level')

# %%
#dfDrugFiltN.age  = dfDrugFiltN.age.map(mean_age_func)

# uncomment and run as needed
#Job['Job_title_filt'] = Job.Job_title.map(job_title_map);

# %%
Job['Job_level'] = Job.Job_title.map(job_level_map);
# Out:
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# no level
# ...

# %%
Job['Job_title'].values;

# %%
### drop all jobs where job_title is no title

# %%
Job =  Job[Job['Job_title'] != 'no title']

# %%
#  drop job date
Job.drop('Job_date', axis =1 , inplace = True)

# %%
Job.head()
# Out:
#                                              Job_url  \
# 0  https://www.seek.com.au/job/39063945?type=stan...
# 1  https://www.seek.com.au/job/39044001?type=stan...
# 2  https://www.seek.com.au/job/39045995?type=stan...
# 3  https://www.seek.com.au/job/39033202?type=stan...
# 4  https://www.seek.com.au/job/39064335?type=stan...
#
#                                         Company_name  \
# 0  Talent – Winner ‘Seek Large Recruitment Ag...
# 1                             Premium IT Recruitment
# 2                                Ambition Technology
# 3                             Hydrogen Group Pty Ltd
# 4                                                NAB
#
#                                            Job_title  Contract1  Salary  \
# 0                                       Data Analyst        NaN  120000
# 1  Data Conversion Analyst - Excel, VBA, SQL - $6...        NaN   65700
# 2                         Data Visualisation Analyst        NaN     NaN
# ...

# %%
Job.Salary.replace(np.nan, 'no salary',inplace = True)

# %%
#JobWS - with salary
JobWS = Job[Job['Salary'] != 'no salary']

# %%
JobWS.head(15)
# Out:
#                                               Job_url  \
# 0   https://www.seek.com.au/job/39063945?type=stan...
# 1   https://www.seek.com.au/job/39044001?type=stan...
# 6   https://www.seek.com.au/job/39054921?type=stan...
# 8   https://www.seek.com.au/job/39040874?type=stan...
# 9   https://www.seek.com.au/job/39036063?type=stan...
# 14  https://www.seek.com.au/job/38992523?type=stan...
# 21  https://www.seek.com.au/job/39072189?type=stan...
# 23  https://www.seek.com.au/job/38985745?type=stan...
# 38  https://www.seek.com.au/job/38922640?type=stan...
# 54  https://www.seek.com.au/job/38965943?type=stan...
# 59  https://www.seek.com.au/job/38892144?type=stan...
# 61  https://www.seek.com.au/job/38978440?type=stan...
# 63  https://www.seek.com.au/job/38910940?type=stan...
# 67  https://www.seek.com.au/job/38992522?type=stan...
# 73  https://www.seek.com.au/job/39006476?type=stan...
#
#                                          Company_name  \
# ...

# %%
# filter with permanent jobs only...Contract1 = zero or NAN

JobWSP =  JobWS[JobWS['Contract1'] != 1]

# %%
# replace NAN with zero....all permanent
JobWSP.Contract1.replace(np.nan,0,inplace = True)
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
JobWSP['Contract1'].replace(0, 'Permanent',inplace = True)
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
JobWSP.head(15)
# Out:
#                                               Job_url  \
# 0   https://www.seek.com.au/job/39063945?type=stan...
# 1   https://www.seek.com.au/job/39044001?type=stan...
# 6   https://www.seek.com.au/job/39054921?type=stan...
# 8   https://www.seek.com.au/job/39040874?type=stan...
# 9   https://www.seek.com.au/job/39036063?type=stan...
# 14  https://www.seek.com.au/job/38992523?type=stan...
# 21  https://www.seek.com.au/job/39072189?type=stan...
# 23  https://www.seek.com.au/job/38985745?type=stan...
# 38  https://www.seek.com.au/job/38922640?type=stan...
# 54  https://www.seek.com.au/job/38965943?type=stan...
# 59  https://www.seek.com.au/job/38892144?type=stan...
# 61  https://www.seek.com.au/job/38978440?type=stan...
# 63  https://www.seek.com.au/job/38910940?type=stan...
# 67  https://www.seek.com.au/job/38992522?type=stan...
# 73  https://www.seek.com.au/job/39006476?type=stan...
#
#                                          Company_name  \
# ...

# %%
#title = 'data analyst mid level'
#Tokenised = nltk.sent_tokenize(title)
#Tokenised
#all_words = [nltk.word_tokenize(sent) for sent in Tokenised]
#Tokenised
#for item in all_words:
#     item.replace('[','').replace(']','')
#     print(all_words)

# %%
JobWSP.Job_title_filt.values
# Out:
# array(['Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        None, 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', None,
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        None, 'Data Analyst', 'Data Analyst', 'Data Analyst',
#        'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Scientist',
#        'Data Analyst', 'Data Analyst', None, 'Data Analyst', None, None,
#        'Data manager', None, None, None, None, None, 'Data manager', None,
#        None, None, None, 'Data manager', None, 'Data manager', None, None,
#        None, None, None, None, None, None, None, 'Data manager',
# ...

# %%
from sklearn.datasets import fetch_20newsgroups

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)

# %%
import pyLDAvis.gensim

# %%
### Target = Job_title_filt
## Data is rest of columns
JobWSP_target = JobWSP['Job_title_filt']

# %%
JobWSP_Data = JobWSP.drop('Job_title_filt', axis =1)

# %%
#JobWSP_Data_Filt = JobWSP[['Job_title','Description']]

# %%
#JobWSP_Data_Filt.head()
# Out:
#                                            Job_title  \
# 0                                       Data Analyst
# 1  Data Conversion Analyst - Excel, VBA, SQL - $6...
# 6                            Commercial Data Analyst
# 8              Japanese-speaking Junior Data Analyst
# 9  Data Analyst - Asset Management Project (Immed...
#
#                                          Description
# 0  ['<div data-automation="mobileTemplate" class=...
# 1  ['<div data-automation="mobileTemplate" class=...
# 6  ['<div data-automation="mobileTemplate" class=...
# 8  ['<div data-automation="mobileTemplate" class=...
# 9  ['<div data-automation="mobileTemplate" class=...

# %%
JobWSP_Data.head(4)
# Out:
#                                              Job_url  \
# 0  https://www.seek.com.au/job/39063945?type=stan...
# 1  https://www.seek.com.au/job/39044001?type=stan...
# 6  https://www.seek.com.au/job/39054921?type=stan...
# 8  https://www.seek.com.au/job/39040874?type=stan...
#
#                                         Company_name  \
# 0  Talent – Winner ‘Seek Large Recruitment Ag...
# 1                             Premium IT Recruitment
# 6                                   Fuse Recruitment
# 8                                 THE CAREER MEISTER
#
#                                            Job_title  Contract1  Salary  \
# 0                                       Data Analyst  Permanent  120000
# 1  Data Conversion Analyst - Excel, VBA, SQL - $6...  Permanent   65700
# 6                            Commercial Data Analyst  Permanent  140000
# 8              Japanese-speaking Junior Data Analyst  Permanent   60225
#
# ...

# %%
#processed_article =     ''.join(processed_article)

#Test = Job_WSP_DV[0]
#processed_article =     ''.join(Test)

#processed_article = processed_article.lower()  
#processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )  
#processed_article = re.sub(r'\s+', ' ', processed_article)
#processed_article
# Out:
# ' div data automation mobiletemplate class e pi b strong about the company xa strong br proudly australian owned and operated utlities comapany they are passionate about understanding the needs of households and small businesses that s why there model is built on better value simplicity and a broader product range br br strong about the role xa strong br in this position you will have the rare and exciting opportunity to develop high volume systems that will be used by clients across the globe br br strong requirement xa strong ul li preferably someone with energy utilities experience li li extensive experience with xa sql etl li li extensive experience with reporting skills ssrs ssis li li someone who can take ownership and see projects through to the end li li small team experiencethis position will suit someone that s come from a utility background with end to end experience in data analytics within sql etl environments aswell as strong reporting skills with ssrs ssis xa li ul str
# ...

# %%
def Description_clean(Test):
    processed =     ''.join(Test)
    processed = processed.lower()  
    processed = re.sub('[^a-zA-Z]', ' ', processed )  
    processed = re.sub(r'\s+', ' ', processed)
    return processed

# %%
JobWSP_Data['Description'] = JobWSP_Data.Description.map(Description_clean)

# %%
#JobWSP_Data_Filt  = JobWSP_Data[['Job_title', 'Description']]

# %%
#temp = JobWSP_Data_Filt[0:3].values

# %%
#tempList = temp.tolist()
#tempList

# %%
JobWSP_Data_Desc_Val =  JobWSP_Data['Description'].values
# Out:
# array([' div data automation mobiletemplate class e pi b strong about the company xa strong br proudly australian owned and operated utlities comapany they are passionate about understanding the needs of households and small businesses that s why there model is built on better value simplicity and a broader product range br br strong about the role xa strong br in this position you will have the rare and exciting opportunity to develop high volume systems that will be used by clients across the globe br br strong requirement xa strong ul li preferably someone with energy utilities experience li li extensive experience with xa sql etl li li extensive experience with reporting skills ssrs ssis li li someone who can take ownership and see projects through to the end li li small team experiencethis position will suit someone that s come from a utility background with end to end experience in data analytics within sql etl environments aswell as strong reporting skills with ssrs ssis xa li
# ...

# %%
#processed_article

# %%
JobWSP_Data_Desc_Val.tolist()

# %%
Job_WSP_DV = JobWSP_Data.Description.values
#Job_WSP_D_Clean

# %%
Job_WSP_DV[0:2]
# Out:
# array([' div data automation mobiletemplate class e pi b strong about the company xa strong br proudly australian owned and operated utlities comapany they are passionate about understanding the needs of households and small businesses that s why there model is built on better value simplicity and a broader product range br br strong about the role xa strong br in this position you will have the rare and exciting opportunity to develop high volume systems that will be used by clients across the globe br br strong requirement xa strong ul li preferably someone with energy utilities experience li li extensive experience with xa sql etl li li extensive experience with reporting skills ssrs ssis li li someone who can take ownership and see projects through to the end li li small team experiencethis position will suit someone that s come from a utility background with end to end experience in data analytics within sql etl environments aswell as strong reporting skills with ssrs ssis xa li
# ...

# %%
Job_WSP_DV[0:2].tolist()
# Out:
# [' div data automation mobiletemplate class e pi b strong about the company xa strong br proudly australian owned and operated utlities comapany they are passionate about understanding the needs of households and small businesses that s why there model is built on better value simplicity and a broader product range br br strong about the role xa strong br in this position you will have the rare and exciting opportunity to develop high volume systems that will be used by clients across the globe br br strong requirement xa strong ul li preferably someone with energy utilities experience li li extensive experience with xa sql etl li li extensive experience with reporting skills ssrs ssis li li someone who can take ownership and see projects through to the end li li small team experiencethis position will suit someone that s come from a utility background with end to end experience in data analytics within sql etl environments aswell as strong reporting skills with ssrs ssis xa li ul st
# ...

# %%
Job_WSP_D_Clean = Job_WSP_DV.tolist()

# %%
def lemmatize_stemming(text):
    stemmer = SnowballStemmer("english")
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# %%
# Tokenize and lemmatize
#def preprocess(text):
#    result=[]
#    for token in gensim.utils.simple_preprocess(text) :
#        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
#            result.append(lemmatize_stemming(token))
#            print(token)
#    return result

# %%
# only Tokenize, don't lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            #result.append(lemmatize_stemming(token))
            result.append(token)
            print(token)
    return result

# %%
processed_docs = []

# %%
for doc in Job_WSP_D_Clean:
    #print(doc)
    processed_docs.append(preprocess(doc))
# Out:
# data
# automation
# mobiletemplate
# class
# strong
# company
# strong
# proudly
# australian
# owned
# operated
# utlities
# comapany
# passionate
# understanding
# needs
# households
# small
# businesses
# model
# built
# better
# value
# simplicity
# broader
# product
# range
# strong
# role
# strong
# position
# rare
# exciting
# opportunity
# develop
# high
# volume
# systems
# clients
# globe
# strong
# requirement
# strong
# preferably
# energy
# utilities
# experience
# extensive
# experience
# extensive
# experience
# reporting
# skills
# ssrs
# ssis
# ownership
# projects
# small
# team
# experiencethis
# position
# suit
# come
# utility
# background
# experience
# data
# analytics
# environments
# aswell
# strong
# reporting
# skills
# ssrs
# ssis
# strong
# experience
# education
# strong
# tertiary
# qualifications
# commercial
# quantitative
# discipline
# example
# statistics
# science
# business
# commerce
# proficiency
# relational
# databases
# experience
# ...

# %%
len(processed_docs)
# Out:
# 143

# %%
processed_docs
# Out:
# [['data',
#   'automation',
#   'mobiletemplate',
#   'class',
#   'strong',
#   'company',
#   'strong',
#   'proudly',
#   'australian',
#   'owned',
#   'operated',
#   'utlities',
#   'comapany',
#   'passionate',
#   'understanding',
#   'needs',
#   'households',
#   'small',
#   'businesses',
#   'model',
#   'built',
#   'better',
#   'value',
#   'simplicity',
#   'broader',
#   'product',
#   'range',
#   'strong',
#   'role',
#   'strong',
#   'position',
#   'rare',
#   'exciting',
#   'opportunity',
#   'develop',
#   'high',
#   'volume',
#   'systems',
#   'clients',
#   'globe',
#   'strong',
#   'requirement',
#   'strong',
#   'preferably',
#   'energy',
#   'utilities',
#   'experience',
#   'extensive',
#   'experience',
#   'extensive',
#   'experience',
#   'reporting',
#   'skills',
#   'ssrs',
#   'ssis',
#   'ownership',
#   'projects',
#   'small',
#   'team',
#   'experiencethis',
#   'position',
#   'suit',
#   'come',
#   'utility',
#   'background',
# ...

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
dictionary.filter_extremes(no_below = 5, no_above = 0.2, keep_n = 100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus,num_topics = 4,id2word = dictionary, passes =10,workers =2)

# %%
lda_display = pyLDAvis.gensim.prepare(lda_model,bow_corpus,dictionary)

# %%
lda_display
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.142255  0.034711       1        1  30.767447
# 1     -0.020477 -0.135299       2        1  23.575237
# 0      0.134082 -0.006777       3        1  23.108574
# 2      0.028650  0.107365       4        1  22.548731, topic_info=     Category       Freq           Term      Total  loglift  logprob
# term
# 908   Default  65.000000          csiro  65.000000  30.0000  30.0000
# 747   Default  61.000000         monash  61.000000  29.0000  29.0000
# 615   Default  82.000000       security  82.000000  28.0000  28.0000
# 764   Default  57.000000     university  57.000000  27.0000  27.0000
# 173   Default  63.000000      financial  63.000000  26.0000  26.0000
# 291   Default  61.000000      marketing  61.000000  25.0000  25.0000
# 21    Default  45.000000        finance  45.000000  24.0000  24.0000
# 154   Default  29.000000           care  29.000000  23.0000  23.0000
# ...

# %%
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el17261124872262486446256531"></div>
# <script type="text/javascript">
#
# ...

# %%
from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
#from sklearn.datasets import fetch_20newsgroups
#https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html
#Non-negative Matrix Factorization is applied with two different objective functions: the Frobenius norm, 
#and the generalized Kullback-Leibler divergence. The latter is equivalent to Probabilistic Latent Semantic 
#Indexing.
#The default parameters (n_samples / n_features / n_components) should make 
#the example runnable in a couple of tens of seconds. 
#You can try to increase the dimensions of the problem, 
#but be aware that the time complexity is polynomial in NMF. 
#In LDA, the time complexity is proportional to (n_samples * iterations).

# %%
n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')
# Out:
# Extracting tf-idf features for NMF...

# %%
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(Job_WSP_D_Clean)
print("done in %0.3fs." % (time() - t0))
# Out:
# done in 0.084s.

# %%
# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')
# Out:
# Extracting tf features for LDA...

# %%
t0 = time()
tf = tf_vectorizer.fit_transform(Job_WSP_D_Clean)
print("done in %0.3fs." % (time() - t0))
print()
# Out:
# done in 0.067s.

# %%
#Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()

nmf = NMF(n_components=n_components, random_state=1,alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))


print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.055s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: li strong ul business experience reporting skills role team financial management work contact requirements amp client analyst company systems apply
# Topic #1: strong monash university xa target blank https project research career href edu jobs apply faculty pageuppeople equity directions ai www
# Topic #2: br strong business experience dha xa working hadoop scripting applications analytics rmit understanding cloud ongoing including service benefits performance team
# Topic #3: xa research strong able consulting em world payroll demonstrate analysis related track oracle assisting team professional help transformation field record
# ...

# %%
print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 0.832s.
#
# Topics in LDA model:
# Topic #0: li spatial ul marketing maritime reporting analysis management role questions project safety resume key waterway officer policy campaign processing information
# Topic #1: strong li ul role experience payroll environment provided working team href providing reputation produce business benefits right market commitment salary
# Topic #2: li xa br strong business ul security financial amp experience years contact href development enterprise managing skills key required management
# Topic #3: li br strong ul analytics xa business skills insights experience advanced models collections role learning work ability trends teams value
# Topic #4: area bring environments like quantitative interpersonal developers sector undertaking non agile residential operating required engineer software mailto studio undergraduate plans
# ...

# %%
### word2vec
import gzip
import gensim 
import logging

logging.basicConfig(format= '%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.XN5BxC1L38M

#CBOW is learning to predict the word by the context . Or maximize the probability of the 
#target word by looking at the context. And this happens to be a problem for rare words. 
#For example, given the context yesterday was a really [...] day CBOW model will tell you that most probably the word is beautiful or nice. Words like delightful will get much less attention of the model, because it is designed to predict the most probable word. 
#This word will be smoothed over a lot of examples with more frequent words.

# %%
# build vocabulary and train model  ....sg = 0, CBOW 
model = gensim.models.Word2Vec(processed_docs,sg = 0, size=10,window=4,min_count=2,workers=10)
# Out:
# 2019-05-24 14:08:25,037 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-05-24 14:08:25,041 : INFO : collecting all words and their counts
# 2019-05-24 14:08:25,042 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-05-24 14:08:25,055 : INFO : collected 3744 word types from a corpus of 31594 raw words and 143 sentences
# 2019-05-24 14:08:25,056 : INFO : Loading a fresh vocabulary
# 2019-05-24 14:08:25,067 : INFO : effective_min_count=2 retains 2556 unique words (68% of original 3744, drops 1188)
# 2019-05-24 14:08:25,068 : INFO : effective_min_count=2 leaves 30406 word corpus (96% of original 31594, drops 1188)
# 2019-05-24 14:08:25,080 : INFO : deleting the raw counts dictionary of 3744 items
# 2019-05-24 14:08:25,081 : INFO : sample=0.001 downsamples 46 most-common words
# 2019-05-24 14:08:25,082 : INFO : downsampling leaves estimated 26149 word corpus (86.0% of prior 30406)
# ...

# %%
len(processed_docs)
# Out:
# 143

# %%
model.train(processed_docs, total_examples=len(processed_docs), epochs=10)
# Out:
# 2019-05-24 14:10:02,921 : WARNING : Effective 'alpha' higher than previous training cycles
# 2019-05-24 14:10:02,923 : INFO : training model with 10 workers on 2556 vocabulary and 10 features, using sg=0 hs=0 sample=0.001 negative=5 window=4
# 2019-05-24 14:10:02,932 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-05-24 14:10:02,941 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-05-24 14:10:02,952 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-05-24 14:10:02,955 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-05-24 14:10:02,957 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-05-24 14:10:02,959 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-05-24 14:10:02,960 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-24 14:10:02,962 : INFO : worker thread finished; awaiting finish of 2 more threads
# ...

# %%
#https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#Saving in binary to save space
model.wv.save_word2vec_format('model.bin')
#When getting started, you can save the learned model in ASCII format and review the contents.

#You can do this by setting binary=False when calling the save_word2vec_format() function, for example
#model.wv.save_word2vec_format('model.txt', binary=False)



#loading the model again
#model = Word2Vec.load('model.bin')
# Out:
# 2019-05-24 14:13:29,476 : INFO : storing 2556x10 projection weights into model.bin
# 2019-05-24 14:13:29,478 : WARNING : this function is deprecated, use smart_open.open instead

# %%
vocabulary = model.wv.vocab
#print(vocabulary)

# %%
#model.evaluate_word_pairs('analyst','scientist')
context_word_list = ['data', 'analysis','science', 'python', 'SQL']

# %%
model.predict_output_word(context_word_list, topn=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b7b493b6ebd> in <module>
# ----> 1 model.predict_output_word(context_word_list, topn=10)
#
# NameError: name 'model' is not defined

# %%
sim_words_analyst = model.wv.most_similar('analyst')

# %%
sim_words_analyst
# Out:
# [('marketing', 0.9680184125900269),
#  ('responsible', 0.954077422618866),
#  ('experienced', 0.9521729946136475),
#  ('salesforce', 0.9514082670211792),
#  ('digital', 0.9474241733551025),
#  ('lead', 0.9406147003173828),
#  ('manager', 0.9394255876541138),
#  ('cyber', 0.9337409138679504),
#  ('team', 0.9316191673278809),
#  ('based', 0.9229862689971924)]

# %%
sim_words_scientist = model.wv.most_similar('scientist')

# %%
sim_words_scientist
# Out:
# [('consultancy', 0.9959532022476196),
#  ('accountant', 0.9951343536376953),
#  ('currently', 0.9949975609779358),
#  ('recruiting', 0.9945607781410217),
#  ('manufacturing', 0.9943975210189819),
#  ('registered', 0.9943151473999023),
#  ('administrator', 0.9937311410903931),
#  ('unique', 0.9935327768325806),
#  ('contracts', 0.9927530288696289),
#  ('growth', 0.9911949038505554)]

# %%
sim_words_manager = model.wv.most_similar('manager') 
sim_words_manager
# Out:
# [('digital', 0.9876937866210938),
#  ('responsible', 0.9862974286079407),
#  ('lead', 0.9824036359786987),
#  ('marketing', 0.981643557548523),
#  ('finance', 0.9794235229492188),
#  ('partnering', 0.9793709516525269),
#  ('journey', 0.9791109561920166),
#  ('understand', 0.9790796041488647),
#  ('team', 0.9787262678146362),
#  ('deliver', 0.9778867959976196)]

# %%
#from gensim.models import Word2Vec
#https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
# define training data
#sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
#			['this', 'is', 'the', 'second', 'sentence'],
#			['yet', 'another', 'sentence'],
#			['one', 'more', 'sentence'],
#			['and', 'the', 'final', 'sentence']]
# train model
#model = Word2Vec(sentences, min_count=1)
#create a 2-dimensional PCA model of the word vectors using the scikit-learn PCA class as follows.
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':

# %%
# create a scatter plot of the projection
# The resulting projection can be plotted using matplotlib as follows, 
#pulling out the two dimensions as x and y coordinates.
#pyplot.scatter(result[:, 0], result[:, 1])

pyplot.figure(figsize = [20,200])

pyplot.scatter(result[:, 0], result[:, 1])

words = list(model.wv.vocab)
for i, word in enumerate(words):
     pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
