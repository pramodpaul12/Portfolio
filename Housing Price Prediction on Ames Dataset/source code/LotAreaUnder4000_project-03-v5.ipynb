# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 3
#
# ### Regression and Classification with the Ames Housing Data
#
# ---
#
# You have just joined a new "full stack" real estate company in Ames, Iowa. The strategy of the firm is two-fold:
# - Own the entire process from the purchase of the land all the way to sale of the house, and anything in between.
# - Use statistical analysis to optimize investment and maximize return.
#
# The company is still small, and though investment is substantial the short-term goals of the company are more oriented towards purchasing existing houses and flipping them as opposed to constructing entirely new houses. That being said, the company has access to a large construction workforce operating at rock-bottom prices.
#
# This project uses the [Ames housing data recently made available on kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use(style = "ggplot")
plt.rcParams['figure.figsize'] = [10,6]

print(__doc__)

import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import load_boston
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
import pandas as pd


sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline


#import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification



from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn import linear_model
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Estimating the value of homes from fixed characteristics.
#
# ---
#
# Your superiors have outlined this year's strategy for the company:
# 1. Develop an algorithm to reliably estimate the value of residential houses based on #fixed characteristics.
# 2. Identify characteristics of houses that the company can cost-effectively change/renovate with their construction team.
# 3. Evaluate the mean dollar value of different renovations.
#
# Then we can use that to buy houses that are likely to sell for more than the cost of the purchase plus renovations.
#
# Your first job is to tackle #1. You have a dataset of housing sale data with a huge amount of features identifying different aspects of the house. The full description of the data features can be found in a separate file:
#
#     housing.csv
#     data_description.txt
#
# You need to build a reliable estimator for the price of the house given characteristics of the house that cannot be renovated. Some examples include:
# - The neighborhood
# - Square feet
# - Bedrooms, bathrooms
# - Basement and garage space
#
# and many more.
#
# Some examples of things that **ARE renovate-able:**
# - Roof and exterior features
# - "Quality" metrics, such as kitchen quality
# - "Condition" metrics, such as condition of garage
# - Heating and electrical components
#
# and generally anything you deem can be modified without having to undergo major construction on the house.
#
# ---
#
# **Your goals:**
# 1. Perform any cleaning, feature engineering, and EDA you deem necessary.
# - Be sure to remove any houses that are not residential from the dataset.
# - Identify **fixed** features that can predict price.
# - Train a model on pre-2010 data and evaluate its performance on the 2010 houses.
# - Characterize your model. How well does it perform? What are the best estimates of price?
#
# > **Note:** The EDA and feature engineering component to this project is not trivial! Be sure to always think critically and creatively. Justify your actions! Use the data description file!

# %%
## EDA
# Load the data
house = pd.read_csv('./housing.csv')

# %%
house.shape
# Out:
# (1460, 81)

# %%
# salesprice skewness
#sns.distplot([house.SalePrice], hist = True, kde = True)

# %%
#plt.hist(house.SalePrice,color = 'Blue' )

# %%
#house.kurtosis()
#house.skew(axis = 0, skipna = True)
#house.SalePrice.describe()

# %%
house.SalePrice.skew()     ### positive skew
# Out:
# 1.8828757597682129

# %%
## do target log transform...np.log..better linearity
##at end  reverse..np.exp
target = np.log(house.SalePrice)
#plt.hist(target,color = 'Blue' )
#target.skew()  #### value closer to zero indicates better skew with log values...

# %%
numeric_features = house.select_dtypes(include=[np.number])

# %%
# displays the correlation between the features columns and the target.
corr = numeric_features.corr()
corr['SalePrice'].sort_values(ascending=False)[:20]
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# Name: SalePrice, dtype: float64

# %%
corr['SalePrice'].sort_values(ascending=False)[-20:]
# Out:
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
house.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
OverallQualPivot = house.pivot_table(values = "SalePrice", index ='OverallQual', aggfunc = np.median)
#OverallQualPivot

# %%
plt.plot(OverallQualPivot, color = 'Blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
#plt.show()
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#to generate some scatter plots and visualize the relationship between the Ground Living Area(GrLivArea) and SalePrice
plt.scatter(x= house['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area sqft')
plt.show()

# %%
# do the same for GarageArea.
plt.scatter(x=house['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %%
#house.GarageArea.unique()   #### has outliers..1200 -1400 sqft

# %%
#house.isnull().sum()   ### look at null values

# %%
cols_with_na = pd.DataFrame(house.isnull().sum().sort_values(ascending=False)[:25])
cols_with_na.columns = ['NA Count']
cols_with_na.index.name = 'Feature'

cols_with_na
# Out:
#               NA Count
# Feature
# PoolQC            1453
# MiscFeature       1406
# Alley             1369
# Fence             1179
# FireplaceQu        690
# LotFrontage        259
# GarageCond          81
# GarageType          81
# GarageYrBlt         81
# GarageFinish        81
# GarageQual          81
# BsmtExposure        38
# BsmtFinType2        38
# BsmtFinType1        37
# BsmtCond            37
# BsmtQual            37
# MasVnrArea           8
# MasVnrType           8
# Electrical           1
# Utilities            0
# YearRemodAdd         0
# MSSubClass           0
# Foundation           0
# ExterCond            0
# ExterQual            0

# %%
house.MiscFeature.unique()   #### MiscFeature with dollar values of renvoations, Tennis court
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
#CLEANING NAN VALUES
#1  Non numericfeatures where NaN values have meaning e.g. no pool etc.
cols_fill_na = ['PoolQC','MiscFeature','Alley','Fence','MasVnrType','FireplaceQu',
               'GarageQual','GarageCond','GarageFinish','GarageType',
               'BsmtExposure','BsmtCond','BsmtQual','BsmtFinType1','BsmtFinType2']

# replace 'NaN' with 'None' in these columns
for col in cols_fill_na:
    house[col].fillna('None',inplace=True)

# %%
#GarageYrBlt nans: no garage. replace with property YearBuilt.
#(more appropriate than 0, which is ~2000 away from all other values)
house.loc[house.GarageYrBlt.isnull(),'GarageYrBlt'] = house.loc[house.GarageYrBlt.isnull(),'YearBuilt']


#No masonry veneer - fill area with 0
house.MasVnrArea.fillna(0,inplace=True)

#No basement - fill areas/counts with 0    
house.BsmtFullBath.fillna(0,inplace=True)
house.BsmtHalfBath.fillna(0,inplace=True)
house.BsmtFinSF1.fillna(0,inplace=True)
house.BsmtFinSF2.fillna(0,inplace=True)
house.BsmtUnfSF.fillna(0,inplace=True)
house.TotalBsmtSF.fillna(0,inplace=True)

#No garage - fill areas/counts with 0
house.GarageArea.fillna(0,inplace=True)
house.GarageCars.fillna(0,inplace=True)

house[cols_fill_na].head(5)
# Out:
#   PoolQC MiscFeature Alley Fence MasVnrType FireplaceQu GarageQual GarageCond  \
# 0   None        None  None  None    BrkFace        None         TA         TA
# 1   None        None  None  None       None          TA         TA         TA
# 2   None        None  None  None    BrkFace          TA         TA         TA
# 3   None        None  None  None       None          Gd         TA         TA
# 4   None        None  None  None    BrkFace          TA         TA         TA
#
#   GarageFinish GarageType BsmtExposure BsmtCond BsmtQual BsmtFinType1  \
# 0          RFn     Attchd           No       TA       Gd          GLQ
# 1          RFn     Attchd           Gd       TA       Gd          ALQ
# 2          RFn     Attchd           Mn       TA       Gd          GLQ
# 3          Unf     Detchd           No       Gd       TA          ALQ
# 4          RFn     Attchd           Av       TA       Gd          GLQ
#
#   BsmtFinType2
# 0          Unf
# 1          Unf
# 2          Unf
# 3          Unf
# 4          Unf

# %%
# LotFrontage NAN values
house.LotFrontage.fillna(0,inplace=True)

# %%
house.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
house.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
house.OverallCond.unique()
# Out:
# array([5, 8, 6, 7, 4, 2, 3, 9, 1])

# %%
house.Neighborhood.unique()
# Out:
# array([ 5. ,  2.5, 10. ,  7. ])

# %%
#house['Neighborhood'].replace({'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0}, inplace=True)

# flood plain rating
house['Neighborhood'].replace({'CollgCr':5, 'Veenker':2.5, 'Crawfor' :10, 'NoRidge':10, 'Mitchel': 2.5, 'Somerst':10,
       'NWAmes' : 10, 'OldTown': 10, 'BrkSide':10, 'Sawyer':10, 'NridgHt':10, 'NAmes':10,
       'SawyerW': 10 , 'IDOTRR': 10, 'MeadowV': 7, 'Edwards':10, 'Timber':10, 'Gilbert':5,
       'StoneBr':10, 'ClearCr':10, 'NPkVill':10, 'Blmngtn':10, 'BrDale':10, 'SWISU':10,
       'Blueste':10}, inplace=True)

# %%
house.Condition1.unique()
# Out:
# array(['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA',
#        'RRNe'], dtype=object)

# %%
#house['Condition1'].replace({'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0}, inplace=True)

house['Condition1'].replace({'Norm':5, 'Feedr':6, 'PosN':10, 'Artery':7, 'RRAe':1, 'RRNn':1, 'RRAn':1, 'PosA':10,
       'RRNe':1}, inplace=True)

# %%
house.Condition2.unique()
# Out:
# array(['Norm', 'Artery', 'RRNn', 'Feedr', 'PosN', 'PosA', 'RRAn', 'RRAe'],
#       dtype=object)

# %%
#house['Condition2'].replace({'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0}, inplace=True)
house['Condition2'].replace({'Norm':5, 'Feedr':6, 'PosN':10, 'Artery':7, 'RRAe':1, 'RRNn':1, 'RRAn':1, 'PosA':10,
       'RRNe':1}, inplace=True)

# %%
# convert some categorical values to numeric scales

#Excellent, Good, Typical, Fair, Poor, None: Convert to 0-5 scale
cols_Ex_None = ['ExterQual','ExterCond','BsmtQual','BsmtCond',
             'HeatingQC','KitchenQual','FireplaceQu','GarageQual',
            'GarageCond','PoolQC']

dict_Ex_None = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'None':0}

for col in cols_Ex_None:
    house[col].replace(dict_Ex_None, inplace=True)

#house[cols_Ex_None].head(5)   

# Remaining columns
house['BsmtExposure'].replace({'Gd':4,'Av':3,'Mn':2,'No':1,'None':0}, inplace=True)

house['CentralAir'].replace({'Y':1,'N':0}, inplace=True)

house['Functional'].replace({'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0}, inplace=True)

house['GarageFinish'].replace({'Fin':3,'RFn':2,'Unf':1,'None':0}, inplace=True)

house['LotShape'].replace({'Reg':3,'IR1':2,'IR2':1,'IR3':0}, inplace=True)

house['Utilities'].replace({'AllPub':3,'NoSewr':2,'NoSeWa':1,'ELO':0}, inplace=True)

house['LandSlope'].replace({'Gtl':2,'Mod':1,'Sev':0}, inplace=True)

# %% [markdown]
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality - 7
#        Min1	Minor Deductions 1     6
#        Min2	Minor Deductions 2      5
#        Mod	Moderate Deductions     4
#        Maj1	Major Deductions 1      3
#        Maj2	Major Deductions 2      2
#        Sev	Severely Damaged        1
#        Sal	Salvage only            0

# %%
house[cols_Ex_None].head(5)
# Out:
#    ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  KitchenQual  \
# 0          4          3         4         3          5            4
# 1          3          3         4         3          5            3
# 2          4          3         4         3          5            4
# 3          3          3         3         4          4            4
# 4          4          3         4         3          5            4
#
#    FireplaceQu  GarageQual  GarageCond  PoolQC
# 0            0           3           3       0
# 1            3           3           3       0
# 2            3           3           3       0
# 3            4           3           3       0
# 4            3           3           3       0

# %%
#Business question:  Develop an algorithm to reliably estimate the value of residential houses 
###based on #fixed characteristics.  >>> Call it  value_fixed 
### 1) Plan  - this step
# 2)Understand the business question
# 3) read the data dictionary
# 4) What all are fixed characteristics of the house that can predict price
#The neighborhood, Square feet, Bedrooms, bathrooms, Basement and garage space
#  renovatable features:  Identify fixed features that can predict price.
#Roof and exterior features
#"Quality" metrics, such as kitchen quality
#"Condition" metrics, such as condition of garage
#Heating and electrical components
#and generally anything you deem can be modified without #having to undergo major construction on the house.
#####  Use Lasso with cross validation to get the 10 fixed variables

### remove any non - residential   -  remove all rows based on non residential from MSZoning column

# %%
# consider the non-numeric features 
categoricals = house.select_dtypes(exclude=[np.number])
#print(categoricals.describe())

# %%
#to remove skew
#  keep only residential houses     
# remove all plots > 4000 sqft lot area
# remove all houses with GRLIVAREA > 1500
# remove all houses with salecondition not normal

# %%
r_house = house[house.MSZoning != 'C (all)']
r_house.MSZoning.value_counts()
# Out:
# RL    1151
# RM     218
# FV      65
# RH      16
# Name: MSZoning, dtype: int64

# %%
r_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1450 non-null int64
# MSSubClass       1450 non-null int64
# MSZoning         1450 non-null object
# LotFrontage      1450 non-null float64
# LotArea          1450 non-null int64
# Street           1450 non-null object
# Alley            1450 non-null object
# LotShape         1450 non-null int64
# LandContour      1450 non-null object
# Utilities        1450 non-null int64
# LotConfig        1450 non-null object
# LandSlope        1450 non-null int64
# Neighborhood     1450 non-null float64
# Condition1       1450 non-null int64
# Condition2       1450 non-null object
# BldgType         1450 non-null object
# HouseStyle       1450 non-null object
# OverallQual      1450 non-null int64
# OverallCond      1450 non-null int64
# YearBuilt        1450 non-null int64
# YearRemodAdd     1450 non-null int64
# RoofStyle        1450 non-null object
# RoofMatl         1450 non-null object
# Exterior1st      1450 non-null object
# Exterior2nd      1450 non-null object
# MasVnrType       1450 non-null object
# MasVnrArea       1450 non-null float64
# ExterQual        1450 non-null int64
# ExterCond        1450 non-null int64
# Foundation       1450 non-null object
# BsmtQual         1450 non-null int64
# BsmtCond         1450 non-null int64
# BsmtExposure     1450 non-null int64
# BsmtFinType1     1450 non-null object
# BsmtFinSF1       1450 non-null int64
# BsmtFinType2     1450 non-null object
# BsmtFinSF2       1450 non-null int64
# BsmtUnfSF        1450 non-null int64
# TotalBsmtSF      1450 non-null int64
# Heating          1450 non-null object
# HeatingQC        1450 non-null int64
# CentralAir       1450 non-null int64
# Electrical       1449 non-null object
# 1stFlrSF         1450 non-null int64
# 2ndFlrSF         1450 non-null int64
# LowQualFinSF     1450 non-null int64
# GrLivArea        1450 non-null int64
# BsmtFullBath     1450 non-null int64
# BsmtHalfBath     1450 non-null int64
# FullBath         1450 non-null int64
# HalfBath         1450 non-null int64
# BedroomAbvGr     1450 non-null int64
# KitchenAbvGr     1450 non-null int64
# KitchenQual      1450 non-null int64
# TotRmsAbvGrd     1450 non-null int64
# Functional       1450 non-null int64
# Fireplaces       1450 non-null int64
# FireplaceQu      1450 non-null int64
# GarageType       1450 non-null object
# GarageYrBlt      1450 non-null float64
# GarageFinish     1450 non-null int64
# GarageCars       1450 non-null int64
# GarageArea       1450 non-null int64
# GarageQual       1450 non-null int64
# GarageCond       1450 non-null int64
# PavedDrive       1450 non-null object
# WoodDeckSF       1450 non-null int64
# OpenPorchSF      1450 non-null int64
# EnclosedPorch    1450 non-null int64
# 3SsnPorch        1450 non-null int64
# ScreenPorch      1450 non-null int64
# PoolArea         1450 non-null int64
# PoolQC           1450 non-null int64
# Fence            1450 non-null object
# MiscFeature      1450 non-null object
# MiscVal          1450 non-null int64
# MoSold           1450 non-null int64
# YrSold           1450 non-null int64
# SaleType         1450 non-null object
# SaleCondition    1450 non-null object
# SalePrice        1450 non-null int64
# dtypes: float64(4), int64(53), object(24)
# memory usage: 928.9+ KB

# %%
r_house.shape
# Out:
# (1450, 81)

# %%
r_house_filt = r_house[r_house.LotArea < 4000]
#& house.SaleCondition == 'normal']

# %%
r_house_filt.shape
# Out:
# (95, 81)

# %%
r_house_filt.GrLivArea.unique()
# Out:
# array([1739,  988, 1224, 1458, 1709, 1525, 1456, 1284, 1248, 1302,  987,
#        1555,  866, 1112, 1626, 1269, 1389, 1365,  630, 1258, 1414, 1072,
#        1826, 1304, 1218, 1322, 1557, 1392, 1368, 1402, 1556, 1200, 1512,
#        1567, 1092, 1441, 1291, 1471, 1501, 1145, 1223, 1229, 1416, 1548,
#        1382, 1266, 1504, 1506, 1344, 2521, 1247, 1252, 1088, 1405, 1452,
#        1708,  796, 1573, 1475, 1646, 1569])

# %%
#r_house_filt1 = r_house_filt[r_house_filt.GrLivArea < 1500]

# %%
r_house_filt.shape
# Out:
# (95, 81)

# %%
r_house_filt.head()
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 56    57         160       FV         24.0     2645   Pave  Pave         3
# 75    76         180       RM         21.0     1596   Pave  None         3
# 87    88         160       FV         40.0     3951   Pave  Pave         3
# 115  116         160       FV         34.0     3230   Pave  Pave         3
# 145  146         160       RM         24.0     2522   Pave  None         3
#
#     LandContour  Utilities    ...     PoolArea  PoolQC  Fence  MiscFeature  \
# 56          Lvl          3    ...            0       0   None         None
# 75          Lvl          3    ...            0       0   GdWo         None
# 87          Lvl          3    ...            0       0   None         None
# 115         Lvl          3    ...            0       0   None         None
# 145         Lvl          3    ...            0       0   None         None
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 56         0      8   2009        WD        Abnorml     172500
# 75         0     11   2009        WD         Normal      91000
# 87         0      6   2009       New        Partial     164500
# 115        0      6   2007        WD         Normal     176000
# 145        0      4   2006        WD         Normal     130000
#
# [5 rows x 81 columns]

# %%
r_house_filt.SaleCondition.value_counts()
# Out:
# Normal     80
# Abnorml     7
# Partial     7
# Family      1
# Name: SaleCondition, dtype: int64

# %%
r_house_final = r_house_filt[r_house_filt['SaleCondition'] == 'Normal']

# %%
r_house_final.shape
# Out:
# (80, 81)

# %%
r_house_final
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 75      76         180       RM         21.0     1596   Pave  None         3
# 115    116         160       FV         34.0     3230   Pave  Pave         3
# 145    146         160       RM         24.0     2522   Pave  None         3
# 180    181         160       FV          0.0     2117   Pave  None         3
# 193    194         160       RM         24.0     2522   Pave  None         3
# 195    196         160       RL         24.0     2280   Pave  None         3
# 204    205          50       RM         50.0     3500   Pave  Grvl         3
# 227    228         160       RM         21.0     1869   Pave  None         3
# 229    230         120       RL         43.0     3182   Pave  None         3
# 232    233         160       RM         21.0     1680   Pave  None         3
# 235    236         160       RM         21.0     1680   Pave  None         3
# 241    242          30       RM         40.0     3880   Pave  None         3
# 344    345         160       RM         36.0     2592   Pave  None         3
# 348    349         160       RL         36.0     2448   Pave  None         3
# 363    364         160       RM         21.0     1680   Pave  None         3
# 385    386         120       RL         43.0     3182   Pave  None         3
# 425    426          60       RM         60.0     3378   Pave  Grvl         3
# 432    433         160       RM         24.0     1920   Pave  None         3
# 434    435         180       RM         21.0     1890   Pave  None         3
# 465    466         120       RM          0.0     3072   Pave  None         3
# 472    473         180       RM         35.0     3675   Pave  None         3
# 482    483          70       RM         50.0     2500   Pave  Pave         3
# 489    490         180       RM         21.0     1526   Pave  None         3
# 490    491         160       RM          0.0     2665   Pave  None         3
# 500    501         160       RM         21.0     1890   Pave  None         3
# 504    505         160       RL         24.0     2308   Pave  None         3
# 559    560         120       RL          0.0     3196   Pave  None         3
# 596    597          70       RM         60.0     3600   Pave  Grvl         3
# 599    600         160       RM         24.0     1950   Pave  None         3
# 603    604         160       FV         30.0     3182   Pave  Pave         3
# ...    ...         ...      ...          ...      ...    ...   ...       ...
# 1007  1008         160       RM         21.0     2217   Pave  None         3
# 1019  1020         120       RL         43.0     3013   Pave  None         3
# 1023  1024         120       RL         43.0     3182   Pave  None         3
# 1029  1030         160       RM         21.0     1680   Pave  None         3
# 1038  1039         160       RM         21.0     1533   Pave  None         3
# 1039  1040         180       RM         21.0     1477   Pave  None         3
# 1068  1069         160       RM         42.0     3964   Pave  None         3
# 1086  1087         160       RM          0.0     1974   Pave  None         3
# 1088  1089         160       RM         24.0     2522   Pave  None         3
# 1089  1090         120       FV         37.0     3316   Pave  Pave         2
# 1091  1092         160       FV         24.0     2160   Pave  Pave         3
# 1097  1098         120       RL          0.0     3696   Pave  None         3
# 1104  1105         160       RM         24.0     2016   Pave  None         3
# 1126  1127         120       RL         53.0     3684   Pave  None         3
# 1160  1161         160       RL         24.0     2280   Pave  None         3
# 1177  1178          50       RM          0.0     3950   Pave  Grvl         3
# 1191  1192         160       FV         24.0     2645   Pave  Pave         3
# 1236  1237         160       RL         36.0     2628   Pave  None         3
# 1251  1252         120       RL          0.0     3136   Pave  None         2
# 1265  1266         160       FV         35.0     3735   Pave  None         3
# 1291  1292         160       RM         21.0     1680   Pave  None         3
# 1304  1305         160       RM         32.0     3363   Pave  None         3
# 1325  1326          30       RM         40.0     3636   Pave  None         3
# 1334  1335         160       RM         24.0     2368   Pave  None         3
# 1358  1359         160       FV          0.0     2117   Pave  None         3
# 1367  1368         160       RM         41.0     2665   Pave  None         3
# 1378  1379         160       RM         21.0     1953   Pave  None         3
# 1405  1406         120       RM         44.0     3842   Pave  None         2
# 1415  1416         120       RL         51.0     3635   Pave  None         3
# 1452  1453         180       RM         35.0     3675   Pave  None         3
#
#      LandContour  Utilities    ...     PoolArea  PoolQC  Fence  MiscFeature  \
# 75           Lvl          3    ...            0       0   GdWo         None
# 115          Lvl          3    ...            0       0   None         None
# 145          Lvl          3    ...            0       0   None         None
# 180          Lvl          3    ...            0       0   None         None
# 193          Lvl          3    ...            0       0   None         None
# 195          Lvl          3    ...            0       0   None         None
# 204          Lvl          3    ...            0       0   MnWw         None
# 227          Lvl          3    ...            0       0   None         None
# 229          Lvl          3    ...            0       0   None         None
# 232          Lvl          3    ...            0       0   None         None
# 235          Lvl          3    ...            0       0   None         None
# 241          Lvl          3    ...            0       0   None         None
# 344          Lvl          3    ...            0       0   None         None
# 348          Lvl          3    ...            0       0   None         None
# 363          Lvl          3    ...            0       0   None         None
# 385          Lvl          3    ...            0       0   None         None
# 425          HLS          3    ...            0       0   None         None
# 432          Lvl          3    ...            0       0   None         None
# 434          Lvl          3    ...            0       0   None         None
# 465          Lvl          3    ...            0       0   None         None
# 472          Lvl          3    ...            0       0   None         None
# 482          Lvl          3    ...            0       0   None         None
# 489          Lvl          3    ...            0       0   None         None
# 490          Lvl          3    ...            0       0   None         None
# 500          Lvl          3    ...            0       0   None         None
# 504          Lvl          3    ...            0       0   None         None
# 559          Lvl          3    ...            0       0   None         None
# 596          Lvl          3    ...            0       0   None         None
# 599          Lvl          3    ...            0       0  GdPrv         None
# 603          Lvl          3    ...            0       0   None         None
# ...          ...        ...    ...          ...     ...    ...          ...
# 1007         Lvl          3    ...            0       0   None         None
# 1019         Lvl          3    ...            0       0   None         None
# 1023         Lvl          3    ...            0       0   None         None
# 1029         Lvl          3    ...            0       0   None         None
# 1038         Lvl          3    ...            0       0   None         None
# 1039         Lvl          3    ...            0       0   None         None
# 1068         Lvl          3    ...            0       0  GdPrv         None
# 1086         Lvl          3    ...            0       0   None         None
# 1088         Lvl          3    ...            0       0   None         None
# 1089         Lvl          3    ...            0       0   None         None
# 1091         Lvl          3    ...            0       0   None         None
# 1097         Lvl          3    ...            0       0   None         None
# 1104         Lvl          3    ...            0       0   None         None
# 1126         Lvl          3    ...            0       0   None         None
# 1160         Lvl          3    ...            0       0   None         None
# 1177         Bnk          3    ...            0       0   None         None
# 1191         Lvl          3    ...            0       0   None         None
# 1236         Lvl          3    ...            0       0   None         None
# 1251         Lvl          3    ...            0       0   None         None
# 1265         Lvl          3    ...            0       0   None         None
# 1291         Lvl          3    ...            0       0   None         None
# 1304         Lvl          3    ...            0       0   None         None
# 1325         Lvl          3    ...            0       0  MnPrv         None
# 1334         Lvl          3    ...            0       0   None         None
# 1358         Lvl          3    ...            0       0   None         None
# 1367         Lvl          3    ...            0       0   None         None
# 1378         Lvl          3    ...            0       0   None         None
# 1405         HLS          3    ...            0       0   None         None
# 1415         Lvl          3    ...            0       0   None         None
# 1452         Lvl          3    ...            0       0   None         None
#
#       MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 75          0     11   2009        WD         Normal      91000
# 115         0      6   2007        WD         Normal     176000
# 145         0      4   2006        WD         Normal     130000
# 180         0      6   2007        WD         Normal     177000
# 193         0      5   2006        WD         Normal     130000
# 195         0      7   2009        WD         Normal     148500
# 204         0      4   2009        WD         Normal     110000
# 227         0      9   2008        WD         Normal     106000
# 229         0      5   2009        WD         Normal     192500
# 232         0      6   2006        WD         Normal      94500
# 235         0      8   2008        WD         Normal      89500
# 241         0      8   2007        WD         Normal     110500
# 344         0      4   2010        WD         Normal      85000
# 348         0     10   2008        WD         Normal     154000
# 363         0      5   2009        WD         Normal     118000
# 385         0      4   2010        WD         Normal     192000
# 425         0      9   2009        WD         Normal     135000
# 432         0      8   2007        WD         Normal     122500
# 434         0      6   2008        WD         Normal      81000
# 465         0      5   2006        WD         Normal     178740
# 472         0      6   2008        WD         Normal     148000
# 482         0      6   2009        WD         Normal     155000
# 489         0      5   2009        WD         Normal      86000
# 490         0      6   2008        WD         Normal     115000
# 500         0      5   2007        WD         Normal     113000
# 504         0      6   2009        WD         Normal     147000
# 559         0     10   2006        WD         Normal     234000
# 596         0     10   2006        WD         Normal     114504
# 599         0      7   2008       COD         Normal     151000
# 603         0      6   2010        WD         Normal     151000
# ...       ...    ...    ...       ...            ...        ...
# 1007        0      8   2009        WD         Normal      88000
# 1019        0      4   2006        WD         Normal     213490
# 1023        0      5   2008        WD         Normal     191000
# 1029        0      5   2006        WD         Normal     118000
# 1038        0      5   2009        WD         Normal      97000
# 1039        0      4   2009        WD         Normal      80000
# 1068        0      6   2006        WD         Normal     151400
# 1086        0      5   2010        WD         Normal      83500
# 1088        0      4   2006        WD         Normal     137500
# 1089        0      4   2006        WD         Normal     197000
# 1091        0      3   2008        WD         Normal     160000
# 1097        0     10   2007        WD         Normal     170000
# 1104        0      4   2007        WD         Normal     106000
# 1126        0      6   2009        WD         Normal     174000
# 1160        0      7   2010        WD         Normal     146000
# 1177        0     12   2009        WD         Normal     115000
# 1191        0     11   2007        WD         Normal     174000
# 1236        0      6   2010        WD         Normal     175500
# 1251        0      3   2006        WD         Normal     171750
# 1265        0      3   2006        WD         Normal     183900
# 1291        0      2   2009        WD         Normal     119500
# 1304        0      4   2006        WD         Normal     130000
# 1325        0      1   2008        WD         Normal      55000
# 1334        0      5   2009        WD         Normal     125000
# 1358        0      6   2010        WD         Normal     177500
# 1367        0      7   2006        WD         Normal     127000
# 1378        0      6   2006        WD         Normal      83000
# 1405        0      1   2008        WD         Normal     275000
# 1415        0      5   2009        WD         Normal     175900
# 1452        0      5   2006        WD         Normal     145000
#
# [80 rows x 81 columns]

# %% [markdown]
# POPULAR NEIGHBORHOODS IN AMES
#
# City Center
# 24th St / Grand Ave
# Woodland St / West St
# Grand Ave / 30th St
# Stange Rd / Pammel Ct
# E 13Th St / Duff Ave
# S Duff Ave / E Lincoln Way
# Iowa State U / N Hyland Ave
# S Duff Ave / Airport Rd
# Lincoln Way / 500th Ave

# %%
r_house_final.Neighborhood.unique()
# Out:
# array([ 7., 10.])

# %%
house_fixed_col =  ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle',  'YearBuilt', 'YearRemodAdd',
       'RoofStyle',  'Exterior1st',  'MasVnrType',
       'MasVnrArea',  'Foundation', 'GarageCars',
         'TotalBsmtSF', 
       '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea',  
        'Functional',         
         'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']

# %%
r_house_fixed = r_house_final[house_fixed_col]
r_house_fixed.head(5)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 75    76         180       RM         21.0     1596   Pave  None         3
# 115  116         160       FV         34.0     3230   Pave  Pave         3
# 145  146         160       RM         24.0     2522   Pave  None         3
# 180  181         160       FV          0.0     2117   Pave  None         3
# 193  194         160       RM         24.0     2522   Pave  None         3
#
#     LandContour LotConfig    ...     1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 75          Lvl    Inside    ...          526       462             0
# 115         Lvl    Corner    ...          729       729             0
# 145         Lvl    Inside    ...          970       739             0
# 180         Lvl    Inside    ...          769       756             0
# 193         Lvl    Inside    ...          970       739             0
#
#      GrLivArea Functional MoSold  YrSold  SaleType SaleCondition SalePrice
# 75         988          7     11    2009        WD        Normal     91000
# 115       1458          7      6    2007        WD        Normal    176000
# 145       1709          3      4    2006        WD        Normal    130000
# 180       1525          7      6    2007        WD        Normal    177000
# 193       1709          3      5    2006        WD        Normal    130000
#
# [5 rows x 35 columns]

# %%
### feature selection..
numeric_fixed = r_house_fixed.select_dtypes(include=[np.number])
numeric_fixed.head(5)
# Out:
#       Id  MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  Neighborhood  \
# 75    76         180         21.0     1596         3          2           7.0
# 115  116         160         34.0     3230         3          2          10.0
# 145  146         160         24.0     2522         3          2          10.0
# 180  181         160          0.0     2117         3          2          10.0
# 193  194         160         24.0     2522         3          2          10.0
#
#      Condition1  Condition2  YearBuilt    ...      GarageCars  TotalBsmtSF  \
# 75            5           5       1973    ...               1          462
# 115           5           5       1999    ...               2          729
# 145           5           5       2004    ...               2          970
# 180           5           5       2000    ...               2          756
# 193           5           5       2004    ...               2          970
#
#      1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  Functional  MoSold  YrSold  \
# 75        526       462             0        988           7      11    2009
# 115       729       729             0       1458           7       6    2007
# 145       970       739             0       1709           3       4    2006
# 180       769       756             0       1525           7       6    2007
# 193       970       739             0       1709           3       5    2006
#
#      SalePrice
# 75       91000
# 115     176000
# 145     130000
# 180     177000
# 193     130000
#
# [5 rows x 22 columns]

# %%
r_house_train = numeric_fixed[numeric_fixed['YrSold'] < 2010]

r_house_test = numeric_fixed[numeric_fixed['YrSold'] == 2010]

# %%
r_house_test.shape
# Out:
# (9, 22)

# %%
r_house_train.shape
# Out:
# (71, 22)

# %%
r_house_train_final = r_house_train.fillna(0)

# %%
X_train = r_house_train_final.drop(['SalePrice'],axis =1)

# %%
y_train = np.log(r_house_train.SalePrice.values)
y_train
# Out:
# array([11.41861479, 12.07823927, 11.77528973, 12.08390501, 11.77528973,
#        11.90834024, 11.60823564, 11.57119437, 12.16785143, 11.45635511,
#        11.4019939 , 11.6127708 , 11.94470788, 11.6784399 , 11.81303006,
#        11.71586631, 11.30220443, 12.09368751, 11.90496755, 11.9511804 ,
#        11.36210258, 11.65268741, 11.6351431 , 11.89818787, 12.36307639,
#        11.64836504, 11.92503512, 12.03469103, 11.34450681, 11.90834024,
#        12.06104687, 12.05815252, 12.09737323, 11.98417831, 11.90090526,
#        11.92503512, 11.51292546, 12.27839331, 11.22524339, 11.72803684,
#        11.9511804 , 12.06104687, 12.01370075, 11.98227263, 12.10625231,
#        11.38509209, 12.27134527, 12.16002871, 11.6784399 , 11.48246626,
#        11.28978191, 11.92768062, 11.8313792 , 12.19095901, 11.98292909,
#        12.04355372, 11.57119437, 12.06681058, 11.65268741, 12.06681058,
#        12.05379521, 12.12214741, 11.69107165, 11.77528973, 10.91508846,
#        11.73606902, 11.75194237, 11.32659589, 12.52452638, 12.07767093,
#        11.88448902])

# %%
#temp = np.log(r_house_train['SalePrice'])
y_train.shape = (71,1)

# %%
X_train.shape
# Out:
# (71, 21)

# %%
## linear regression for fixed
##instantiate the model.
lr = linear_model.LinearRegression(normalize = True)

#  Model fitting

lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
###Doing all data wrangling for X_test, y_test as for train

# %%
r_house_test_final = r_house_test.fillna(0)

# %%
X_test = r_house_test_final.drop(['SalePrice'],axis =1)

# %%
predictions = lr.predict(X_test)
predictions
# Out:
# array([[11.49908986],
#        [12.03668012],
#        [11.97619205],
#        [11.17910076],
#        [11.99651158],
#        [11.46685447],
#        [11.89194652],
#        [12.10154794],
#        [12.07377183]])

# %%
r_house_test_final.SalePrice.values
# Out:
# array([ 85000, 192000, 151000,  75500, 155000,  83500, 146000, 175500,
#        177500])

# %%
r_house_train;

# %%
y_test = np.log(r_house_test_final.SalePrice.values)
y_test
# Out:
# array([11.35040654, 12.16525065, 11.92503512, 11.23188794, 11.9511804 ,
#        11.33260191, 11.8913619 , 12.07539432, 12.08672589])

# %%
# ---- Evaluate Model performance and visualize results
# r-squared value is a measure of how close the data are to the fitted regression line
# a higher r-squared value means a better fit(very close to value 1)
print("R^2 is: \n", lr.score(X_test, y_test))


print('RMSE is: ')
mean_squared_error(y_test, predictions)
# Out:
# R^2 is:
#  0.9397087736221454
# RMSE is:
# 0.0072190503584142925

# %%
print('Intercept: \n', lr.intercept_)
print('Coefficients: \n', lr.coef_)
#print_model = lr.summary()
#print(print_model)
# Out:
# Intercept:
#  [-1.67898461]
# Coefficients:
#  [[-4.91166250e-05  1.02460515e-03 -1.93506949e-03  7.58704648e-05
#   -4.77101203e-02 -2.47418852e-01  4.71430323e-02 -1.19904740e-01
#    2.77555756e-17  1.38572488e-03  4.94212005e-03 -5.94340324e-05
#    4.14748352e-02  2.12748674e-04  1.07200131e-04  1.65079770e-04
#   -4.52609135e-04  3.09710884e-04  1.00123503e-01  8.36525064e-03
#   -3.93130770e-05]]

# %%
import statsmodels as sm
#print_model = varmodel.summary()
#print(print_model)

# %%
actual_values = y_test
  
            
plt.scatter(np.exp(predictions), np.exp(actual_values), alpha=.75, color='b')  # alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %%
print(np.exp(predictions))
print('/n')
print(np.exp(actual_values))
# Out:
# [[ 98625.96624145]
#  [168835.49603331]
#  [158925.69543476]
#  [ 71617.93139475]
#  [162188.02279038]
#  [ 95497.41584311]
#  [146085.37919761]
#  [180150.50822675]
#  [175215.48397897]]
# /n
# [ 85000. 192000. 151000.  75500. 155000.  83500. 146000. 175500. 177500.]

# %%
# Appending the predicted values to the  housing dataframe to do DF calcs


#Add predicted values to fixed_char_ DF
Fixed_Predictions = lr.predict(X_train)

r_house_train_final['FixedPredicted'] = np.exp(Fixed_Predictions)

# %%
#Fixed_Predictions

# %%
# Residuals equals the difference between Y-True and Y-Pred
r_house_train_final['Residuals'] = abs(r_house_train_final['SalePrice']- r_house_train_final['FixedPredicted'])

# %%
#r_house_train_final.head(10)
#r_house_train_final.drop('Predicted', axis = 1, inplace = True)

# %%
r_house_train_final;

# %%
r_house_train_final.shape
# Out:
# (71, 24)

# %%
r_house_test_final['FixedPredicted'] = np.exp(predictions)

# %%
r_house_test_final['Residuals'] = abs(r_house_test_final['SalePrice']-r_house_test_final['FixedPredicted'])

# %%
#r_house_test_final.drop('Predicted', axis = 1, inplace = True)

# %%
r_house_test_final.shape
# Out:
# (9, 24)

# %%
r_house_test_final;

# %% [markdown]
# Neighborhood: Physical locations within Ames city limits
#                                                   Add flood plain overlay
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker

# %%
### concat both dataframes together  ...new Df = df1.append(df2)
r_house_fixed_combined =    r_house_train_final.append(r_house_test_final)

# %%
##do standardisation
#scaler = StandardScaler.fit(X_train)
#standardised_X = scaler.transform(X_train)
#standardised_X_test = scaler.transform(X_test)
#scaler = StandardScaler.fit(X)
#standardised_X = scaler.transform(X)
#standardised_X_test = scaler.transform(X_test)

#from sklearn.preprocessing import StandardScaler

#ss = StandardScaler()
#Xn = ss.fit_transform(X)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Determine any value of *changeable* property characteristics unexplained by the *fixed* ones.
#
# ---
#
# Now that you have a model that estimates the price of a house based on its static characteristics, we can move forward with part 2 and 3 of the plan: what are the costs/benefits of quality, condition, and renovations?
#
# There are two specific requirements for these estimates:
# 1. The estimates of effects must be in terms of dollars added or subtracted from the house value.
# 2. The effects must be on the variance in price remaining from the first model.
#
# The residuals from the first model (training and testing) represent the variance in price unexplained by the fixed characteristics. Of that variance in price remaining, how much of it can be explained by the easy-to-change aspects of the property?
#
# ---
#
# **Your goals:**
# 1. Evaluate the effect in dollars of the renovate-able features.
# - How would your company use this second model and its coefficients to determine whether they should buy a property or not? Explain how the company can use the two models you have built to determine if they can make money.
# - Investigate how much of the variance in price remaining is explained by these features.
# - Do you trust your model? Should it be used to evaluate which properties to buy and fix up?

# %%
#Some examples of things that ARE renovate-able:
#Roof and exterior features
#"Quality" metrics, such as kitchen quality
#"Condition" metrics, such as condition of garage
#Heating and electrical components
#and generally anything you deem can be modified without having to undergo major construction on the house.


#house_var_col = ['Id', 'Neighborhood',  'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 
#'RoofStyle', 'RoofMatl',  'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',  'BsmtQual',
#'BsmtCond', 'BsmtFinType2', 'BsmtUnfSF',  'Heating',
#       'HeatingQC', 'CentralAir', 'Electrical', 
#        'BsmtHalfBath', 
#       'HalfBath',   'KitchenQual',
#       'TotRmsAbvGrd', 'Functional',  'FireplaceQu', 
#       'GarageQual',
#       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#       'SaleCondition', 'SalePrice']

# %%
house_var_col = ['Id','Utilities', 'OverallQual', 'OverallCond','YearBuilt', 'YearRemodAdd',  
'RoofStyle', 'RoofMatl',  'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',  'BsmtQual',
'BsmtCond', 'BsmtFinType2', 'BsmtUnfSF',  'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', 
        'BsmtHalfBath', 
       'HalfBath',   'KitchenQual',
          'FireplaceQu', 
       'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal','YrSold' , 'SaleType',
       'SaleCondition', 'SalePrice']

# %%
#r_house_final

# %%
r_house_VarFeat = r_house_final[house_var_col]

# %%
#r_house_VarFeat.Functional.value_counts

# %%
r_house_VarFeat.shape
# Out:
# (80, 42)

# %%
r_house_VarFeat.head(4)
# Out:
#       Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 75    76          3            4            5       1973          1973
# 115  116          3            6            5       1999          1999
# 145  146          3            6            5       2004          2006
# 180  181          3            6            5       2000          2000
#
#     RoofStyle RoofMatl Exterior2nd MasVnrType    ...      ScreenPorch  \
# 75      Gable  CompShg     CmentBd       None    ...                0
# 115     Gable  CompShg     MetalSd    BrkFace    ...                0
# 145     Gable  CompShg     VinylSd      Stone    ...                0
# 180     Gable  CompShg     MetalSd    BrkFace    ...                0
#
#      PoolArea  PoolQC  Fence  MiscFeature MiscVal  YrSold SaleType  \
# 75          0       0   GdWo         None       0    2009       WD
# 115         0       0   None         None       0    2007       WD
# 145         0       0   None         None       0    2006       WD
# 180         0       0   None         None       0    2007       WD
#
#      SaleCondition  SalePrice
# 75          Normal      91000
# 115         Normal     176000
# 145         Normal     130000
# 180         Normal     177000
#
# [4 rows x 42 columns]

# %%
r_house_fixed_combined.shape
# Out:
# (80, 24)

# %%
r_house_fixed_combined.head(3)
# Out:
#       Id  MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  Neighborhood  \
# 75    76         180         21.0     1596         3          2           7.0
# 115  116         160         34.0     3230         3          2          10.0
# 145  146         160         24.0     2522         3          2          10.0
#
#      Condition1  Condition2  YearBuilt     ...       1stFlrSF  2ndFlrSF  \
# 75            5           5       1973     ...            526       462
# 115           5           5       1999     ...            729       729
# 145           5           5       2004     ...            970       739
#
#      LowQualFinSF  GrLivArea  Functional  MoSold  YrSold  SalePrice  \
# 75              0        988           7      11    2009      91000
# 115             0       1458           7       6    2007     176000
# 145             0       1709           3       4    2006     130000
#
#      FixedPredicted    Residuals
# 75     94073.086582  3073.086582
# 115   168547.372380  7452.627620
# 145   139259.797510  9259.797510
#
# [3 rows x 24 columns]

# %%
temp_df = r_house_fixed_combined[['Id' , 'FixedPredicted']]

# %%
temp_df.head(3)
# Out:
#       Id  FixedPredicted
# 75    76    94073.086582
# 115  116   168547.372380
# 145  146   139259.797510

# %%
##pd.merge(df1, df2, on='employee')

# %%
 FDF = pd.merge(r_house_VarFeat, temp_df, on='Id')

# %%
#FDF.shape
FDF
# Out:
#       Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0     76          3            4            5       1973          1973
# 1    116          3            6            5       1999          1999
# 2    146          3            6            5       2004          2006
# 3    181          3            6            5       2000          2000
# 4    194          3            7            5       2004          2004
# 5    196          3            6            6       1976          1976
# 6    205          3            5            7       1947          1950
# 7    228          3            6            6       1970          1970
# 8    230          3            7            5       2005          2006
# 9    233          3            6            5       1972          1972
# 10   236          3            6            3       1971          1971
# 11   242          3            5            9       1945          1997
# 12   345          3            5            3       1976          1976
# 13   349          3            7            5       2003          2004
# 14   364          3            6            8       1972          2007
# 15   386          3            8            5       2004          2005
# 16   426          3            7            8       1946          1992
# 17   433          3            5            5       1971          1971
# 18   435          3            4            7       1972          1972
# 19   466          3            7            5       2004          2004
# 20   473          3            6            5       2005          2005
# 21   483          3            7            8       1915          2005
# 22   490          3            4            8       1970          2002
# 23   491          3            5            6       1976          1976
# 24   501          3            6            5       1973          1973
# 25   505          3            6            5       1974          1974
# 26   560          3            7            5       2003          2004
# 27   597          3            6            7       1910          1993
# 28   600          3            6            6       1980          1980
# 29   604          3            7            5       2004          2005
# ..   ...        ...          ...          ...        ...           ...
# 50  1008          3            4            4       1970          1970
# 51  1020          3            7            5       2005          2005
# 52  1024          3            7            5       2005          2006
# 53  1030          3            6            7       1972          1972
# 54  1039          3            4            6       1970          2008
# 55  1040          3            4            4       1970          1970
# 56  1069          3            6            4       1973          1973
# 57  1087          3            4            5       1973          1973
# 58  1089          3            7            5       2004          2004
# 59  1090          3            8            5       2005          2005
# 60  1092          3            7            5       1999          2000
# 61  1098          3            8            5       1986          1986
# 62  1105          3            5            5       1970          1970
# 63  1127          3            7            5       2007          2007
# 64  1161          3            6            5       1978          1978
# 65  1178          3            6            8       1926          2004
# 66  1192          3            8            5       1999          2000
# 67  1237          3            7            5       2003          2003
# 68  1252          3            7            5       2003          2003
# 69  1266          3            7            5       1999          1999
# 70  1292          3            5            7       1972          1972
# 71  1305          3            7            5       2004          2004
# 72  1326          3            4            4       1922          1950
# 73  1335          3            5            6       1970          1970
# 74  1359          3            6            5       2000          2000
# 75  1368          3            5            6       1977          1977
# 76  1379          3            6            5       1973          1973
# 77  1406          3            8            5       2004          2005
# 78  1416          3            7            5       2007          2007
# 79  1453          3            5            5       2005          2005
#
#    RoofStyle RoofMatl Exterior2nd MasVnrType       ...        PoolArea  \
# 0      Gable  CompShg     CmentBd       None       ...               0
# 1      Gable  CompShg     MetalSd    BrkFace       ...               0
# 2      Gable  CompShg     VinylSd      Stone       ...               0
# 3      Gable  CompShg     MetalSd    BrkFace       ...               0
# 4      Gable  CompShg     VinylSd      Stone       ...               0
# 5      Gable  CompShg     Brk Cmn       None       ...               0
# 6      Gable  CompShg     AsbShng       None       ...               0
# 7      Gable  CompShg     HdBoard    BrkFace       ...               0
# 8      Gable  CompShg     VinylSd    BrkFace       ...               0
# 9      Gable  CompShg     HdBoard    BrkFace       ...               0
# 10     Gable  CompShg     HdBoard    BrkFace       ...               0
# 11     Gable  CompShg     VinylSd       None       ...               0
# 12     Gable  CompShg     CmentBd       None       ...               0
# 13     Gable  CompShg     Wd Shng      Stone       ...               0
# 14     Gable  CompShg     HdBoard    BrkFace       ...               0
# 15     Gable  CompShg     VinylSd    BrkFace       ...               0
# 16     Gable  CompShg     HdBoard       None       ...               0
# 17     Gable  CompShg     HdBoard    BrkFace       ...               0
# 18     Gable  CompShg     CmentBd       None       ...               0
# 19       Hip  CompShg     VinylSd    BrkFace       ...               0
# 20     Gable  CompShg     VinylSd    BrkFace       ...               0
# 21     Gable  CompShg      Stucco       None       ...               0
# 22     Gable  CompShg     CmentBd       None       ...               0
# 23     Gable  CompShg     CmentBd       None       ...               0
# 24     Gable  CompShg     HdBoard    BrkFace       ...               0
# 25     Gable  CompShg     Brk Cmn       None       ...               0
# 26     Gable  CompShg     VinylSd    BrkFace       ...               0
# 27     Gable  CompShg     VinylSd       None       ...               0
# 28     Gable  CompShg     MetalSd       None       ...               0
# 29     Gable  CompShg     MetalSd       None       ...               0
# ..       ...      ...         ...        ...       ...             ...
# 50     Gable  CompShg     CmentBd       None       ...               0
# 51     Gable  CompShg     VinylSd    BrkFace       ...               0
# 52     Gable  CompShg     VinylSd    BrkFace       ...               0
# 53     Gable  CompShg     HdBoard    BrkFace       ...               0
# 54     Gable  CompShg     CmentBd       None       ...               0
# 55     Gable  CompShg     CmentBd       None       ...               0
# 56     Gable  CompShg     CmentBd       None       ...               0
# 57     Gable  CompShg     CmentBd       None       ...               0
# 58     Gable  CompShg     VinylSd      Stone       ...               0
# 59     Gable  CompShg     MetalSd       None       ...               0
# 60     Gable  CompShg     MetalSd    BrkFace       ...               0
# 61     Gable  CompShg     HdBoard       None       ...               0
# 62     Gable  CompShg     HdBoard    BrkFace       ...               0
# 63       Hip  CompShg     VinylSd    BrkFace       ...               0
# 64     Gable  CompShg     Brk Cmn       None       ...               0
# 65     Gable  CompShg     MetalSd       None       ...               0
# 66     Gable  CompShg     MetalSd    BrkFace       ...               0
# 67     Gable  CompShg     Wd Shng      Stone       ...               0
# 68     Gable  CompShg     Wd Shng      Stone       ...               0
# 69       Hip  CompShg     MetalSd    BrkFace       ...               0
# 70     Gable  CompShg     CmentBd    BrkFace       ...               0
# 71     Gable  CompShg     VinylSd      Stone       ...               0
# 72     Gable  CompShg     AsbShng       None       ...               0
# 73     Gable  CompShg     HdBoard       None       ...               0
# 74     Gable  CompShg     MetalSd    BrkFace       ...               0
# 75     Gable  CompShg     CmentBd       None       ...               0
# 76     Gable  CompShg     HdBoard    BrkFace       ...               0
# 77       Hip  CompShg     CmentBd      Stone       ...               0
# 78       Hip  CompShg     VinylSd    BrkFace       ...               0
# 79     Gable  CompShg     VinylSd    BrkFace       ...               0
#
#     PoolQC  Fence  MiscFeature  MiscVal YrSold  SaleType SaleCondition  \
# 0        0   GdWo         None        0   2009        WD        Normal
# 1        0   None         None        0   2007        WD        Normal
# 2        0   None         None        0   2006        WD        Normal
# 3        0   None         None        0   2007        WD        Normal
# 4        0   None         None        0   2006        WD        Normal
# 5        0   None         None        0   2009        WD        Normal
# 6        0   MnWw         None        0   2009        WD        Normal
# 7        0   None         None        0   2008        WD        Normal
# 8        0   None         None        0   2009        WD        Normal
# 9        0   None         None        0   2006        WD        Normal
# 10       0   None         None        0   2008        WD        Normal
# 11       0   None         None        0   2007        WD        Normal
# 12       0   None         None        0   2010        WD        Normal
# 13       0   None         None        0   2008        WD        Normal
# 14       0   None         None        0   2009        WD        Normal
# 15       0   None         None        0   2010        WD        Normal
# 16       0   None         None        0   2009        WD        Normal
# 17       0   None         None        0   2007        WD        Normal
# 18       0   None         None        0   2008        WD        Normal
# 19       0   None         None        0   2006        WD        Normal
# 20       0   None         None        0   2008        WD        Normal
# 21       0   None         None        0   2009        WD        Normal
# 22       0   None         None        0   2009        WD        Normal
# 23       0   None         None        0   2008        WD        Normal
# 24       0   None         None        0   2007        WD        Normal
# 25       0   None         None        0   2009        WD        Normal
# 26       0   None         None        0   2006        WD        Normal
# 27       0   None         None        0   2006        WD        Normal
# 28       0  GdPrv         None        0   2008       COD        Normal
# 29       0   None         None        0   2010        WD        Normal
# ..     ...    ...          ...      ...    ...       ...           ...
# 50       0   None         None        0   2009        WD        Normal
# 51       0   None         None        0   2006        WD        Normal
# 52       0   None         None        0   2008        WD        Normal
# 53       0   None         None        0   2006        WD        Normal
# 54       0   None         None        0   2009        WD        Normal
# 55       0   None         None        0   2009        WD        Normal
# 56       0  GdPrv         None        0   2006        WD        Normal
# 57       0   None         None        0   2010        WD        Normal
# 58       0   None         None        0   2006        WD        Normal
# 59       0   None         None        0   2006        WD        Normal
# 60       0   None         None        0   2008        WD        Normal
# 61       0   None         None        0   2007        WD        Normal
# 62       0   None         None        0   2007        WD        Normal
# 63       0   None         None        0   2009        WD        Normal
# 64       0   None         None        0   2010        WD        Normal
# 65       0   None         None        0   2009        WD        Normal
# 66       0   None         None        0   2007        WD        Normal
# 67       0   None         None        0   2010        WD        Normal
# 68       0   None         None        0   2006        WD        Normal
# 69       0   None         None        0   2006        WD        Normal
# 70       0   None         None        0   2009        WD        Normal
# 71       0   None         None        0   2006        WD        Normal
# 72       0  MnPrv         None        0   2008        WD        Normal
# 73       0   None         None        0   2009        WD        Normal
# 74       0   None         None        0   2010        WD        Normal
# 75       0   None         None        0   2006        WD        Normal
# 76       0   None         None        0   2006        WD        Normal
# 77       0   None         None        0   2008        WD        Normal
# 78       0   None         None        0   2009        WD        Normal
# 79       0   None         None        0   2006        WD        Normal
#
#     SalePrice  FixedPredicted
# 0       91000    94073.086582
# 1      176000   168547.372380
# 2      130000   139259.797510
# 3      177000   178920.175201
# 4      130000   138720.989768
# 5      148500   151255.794380
# 6      110000   100509.365127
# 7      106000   103701.316617
# 8      192500   199426.867811
# 9       94500    99929.455212
# 10      89500    99126.312580
# 11     110500   103912.538853
# 12      85000    98625.966241
# 13     154000   192911.837963
# 14     118000   115568.308916
# 15     192000   168835.496033
# 16     135000   129667.134153
# 17     122500   118772.296928
# 18      81000    75106.166492
# 19     178740   198162.708923
# 20     148000   151476.954331
# 21     155000   130528.213604
# 22      86000    87107.834277
# 23     115000   110480.111339
# 24     113000   114986.808076
# 25     147000   137177.657246
# 26     234000   220021.547575
# 27     114504   127177.221739
# 28     151000   152230.375015
# 29     151000   158925.695435
# ..        ...             ...
# 50      88000    94342.426207
# 51     213490   181308.146886
# 52     191000   186718.194086
# 53     118000   109601.506676
# 54      97000   112146.329551
# 55      80000    71514.622321
# 56     151400   148235.156305
# 57      83500    95497.415843
# 58     137500   131649.095840
# 59     197000   173337.586727
# 60     160000   138737.310828
# 61     170000   153606.651053
# 62     106000   117363.992982
# 63     174000   204568.817258
# 64     146000   146085.379198
# 65     115000   115000.000000
# 66     174000   170034.825644
# 67     175500   180150.508227
# 68     171750   195195.690899
# 69     183900   168374.908937
# 70     119500   109171.433641
# 71     130000   136227.962232
# 72      55000    69634.905592
# 73     125000   114342.292609
# 74     177500   175215.483979
# 75     127000   117376.134035
# 76      83000    96410.984397
# 77     275000   275000.000000
# 78     175900   201764.152116
# 79     145000   143167.114354
#
# [80 rows x 43 columns]

# %%
FDF['Residuals'] = abs( FDF['SalePrice'] - FDF['FixedPredicted'] )

# %%
FDF.shape
# Out:
# (80, 44)

# %%
FDF.head(3)
# Out:
#     Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   76          3            4            5       1973          1973
# 1  116          3            6            5       1999          1999
# 2  146          3            6            5       2004          2006
#
#   RoofStyle RoofMatl Exterior2nd MasVnrType     ...       PoolQC  Fence  \
# 0     Gable  CompShg     CmentBd       None     ...            0   GdWo
# 1     Gable  CompShg     MetalSd    BrkFace     ...            0   None
# 2     Gable  CompShg     VinylSd      Stone     ...            0   None
#
#    MiscFeature  MiscVal  YrSold SaleType  SaleCondition SalePrice  \
# 0         None        0    2009       WD         Normal     91000
# 1         None        0    2007       WD         Normal    176000
# 2         None        0    2006       WD         Normal    130000
#
#    FixedPredicted    Residuals
# 0    94073.086582  3073.086582
# 1   168547.372380  7452.627620
# 2   139259.797510  9259.797510
#
# [3 rows x 44 columns]

# %%
FDF.columns
# Out:
# Index(['Id', 'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtFinType2', 'BsmtUnfSF', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'BsmtHalfBath', 'HalfBath', 'KitchenQual', 'FireplaceQu',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'FixedPredicted', 'Residuals'],
#       dtype='object')

# %%
FDF_num =     FDF.select_dtypes(include=[np.number])

# %%
FDF_num.head(3)
# Out:
#     Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   76          3            4            5       1973          1973
# 1  116          3            6            5       1999          1999
# 2  146          3            6            5       2004          2006
#
#    MasVnrArea  ExterQual  ExterCond  BsmtQual     ...       EnclosedPorch  \
# 0         0.0          3          3         4     ...                   0
# 1      1129.0          3          3         4     ...                   0
# 2        50.0          4          3         4     ...                   0
#
#    3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  YrSold  SalePrice  \
# 0          0            0         0       0        0    2009      91000
# 1          0            0         0       0        0    2007     176000
# 2          0            0         0       0        0    2006     130000
#
#    FixedPredicted    Residuals
# 0    94073.086582  3073.086582
# 1   168547.372380  7452.627620
# 2   139259.797510  9259.797510
#
# [3 rows x 32 columns]

# %%
### where renovations were done
#FDF_REMOD = FDF_num[FDF['YearBuilt'] != FDF['YearRemodAdd']]
# we  will take both houses which were renovated and which were not

# %%
#  prepare Train and test for residuals
#first prepare train  
##  REMOVE houses where remodel add and year built are same
#  

RHV_T1  = FDF_num[FDF_num['YrSold'] < 2010]
#RHV_train = RHV_T1.dropna(0)

# %%
RHV_T1.head(3)
# Out:
#     Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   76          3            4            5       1973          1973
# 1  116          3            6            5       1999          1999
# 2  146          3            6            5       2004          2006
#
#    MasVnrArea  ExterQual  ExterCond  BsmtQual     ...       EnclosedPorch  \
# 0         0.0          3          3         4     ...                   0
# 1      1129.0          3          3         4     ...                   0
# 2        50.0          4          3         4     ...                   0
#
#    3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  YrSold  SalePrice  \
# 0          0            0         0       0        0    2009      91000
# 1          0            0         0       0        0    2007     176000
# 2          0            0         0       0        0    2006     130000
#
#    FixedPredicted    Residuals
# 0    94073.086582  3073.086582
# 1   168547.372380  7452.627620
# 2   139259.797510  9259.797510
#
# [3 rows x 32 columns]

# %%
RHV_T1.shape
# Out:
# (71, 32)

# %%
RHV_train = RHV_T1

# %%
RHV_train.head(3)
# Out:
#     Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   76          3            4            5       1973          1973
# 1  116          3            6            5       1999          1999
# 2  146          3            6            5       2004          2006
#
#    MasVnrArea  ExterQual  ExterCond  BsmtQual     ...       EnclosedPorch  \
# 0         0.0          3          3         4     ...                   0
# 1      1129.0          3          3         4     ...                   0
# 2        50.0          4          3         4     ...                   0
#
#    3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  YrSold  SalePrice  \
# 0          0            0         0       0        0    2009      91000
# 1          0            0         0       0        0    2007     176000
# 2          0            0         0       0        0    2006     130000
#
#    FixedPredicted    Residuals
# 0    94073.086582  3073.086582
# 1   168547.372380  7452.627620
# 2   139259.797510  9259.797510
#
# [3 rows x 32 columns]

# %%
RHV_train.shape
# Out:
# (71, 32)

# %%
RHV_T2 = FDF_num[FDF_num['YrSold'] == 2010]
RHV_test = RHV_T2

# %%
RHV_test
## YearRemodAdd: Remodel date (same as construction date if no remodeling or add
# Out:
#       Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 12   345          3            5            3       1976          1976
# 15   386          3            8            5       2004          2005
# 29   604          3            7            5       2004          2005
# 30   615          3            4            6       1972          1972
# 44   960          3            7            5       1999          1999
# 57  1087          3            4            5       1973          1973
# 64  1161          3            6            5       1978          1978
# 67  1237          3            7            5       2003          2003
# 74  1359          3            6            5       2000          2000
#
#     MasVnrArea  ExterQual  ExterCond  BsmtQual      ...       EnclosedPorch  \
# 12         0.0          3          3         4      ...                   0
# 15        16.0          4          3         4      ...                   0
# 29         0.0          4          3         4      ...                   0
# 30         0.0          3          3         4      ...                   0
# 44         0.0          4          3         4      ...                   0
# 57         0.0          3          3         3      ...                   0
# 64         0.0          3          3         4      ...                   0
# 67       106.0          4          3         4      ...                   0
# 74       216.0          4          3         4      ...                   0
#
#     3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  YrSold  SalePrice  \
# 12          0            0         0       0        0    2010      85000
# 15          0          144         0       0        0    2010     192000
# 29          0            0         0       0        0    2010     151000
# 30          0            0         0       0        0    2010      75500
# 44          0            0         0       0        0    2010     155000
# 57          0            0         0       0        0    2010      83500
# 64          0            0         0       0        0    2010     146000
# 67          0            0         0       0        0    2010     175500
# 74          0            0         0       0        0    2010     177500
#
#     FixedPredicted     Residuals
# 12    98625.966241  13625.966241
# 15   168835.496033  23164.503967
# 29   158925.695435   7925.695435
# 30    71617.931395   3882.068605
# 44   162188.022790   7188.022790
# 57    95497.415843  11997.415843
# 64   146085.379198     85.379198
# 67   180150.508227   4650.508227
# 74   175215.483979   2284.516021
#
# [9 rows x 32 columns]

# %%
#print(RHV_test[1:2].values)

# %%
y_train_var = RHV_train.Residuals.values
#y_train_var
#RHV_train.Residuals.values

# %%
X_train_var = RHV_train.drop(['Residuals'], axis =1)

# %%
### remove all columns..which are not needed
reduced_var_col = ['Id', 'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt',
       'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
       'BsmtFinType2', 'BsmtUnfSF', 'Heating', 'HeatingQC', 'CentralAir',
       'Electrical', 'BsmtHalfBath', 'HalfBath', 'KitchenQual', 'FireplaceQu',
       'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice', 'FixedPredicted', 'Residuals']

# %%
#RHV_train
RHV_test.Residuals.values
# Out:
# array([13625.96624145, 23164.50396669,  7925.69543476,  3882.06860525,
#         7188.02279038, 11997.41584311,    85.37919761,  4650.50822675,
#         2284.51602103])

# %%
y_test_var = RHV_test.Residuals.values
y_test_var
# Out:
# array([13625.96624145, 23164.50396669,  7925.69543476,  3882.06860525,
#         7188.02279038, 11997.41584311,    85.37919761,  4650.50822675,
#         2284.51602103])

# %%
X_test_var = RHV_test.drop(['Residuals'], axis =1)

# %%
X_train_var.shape
# Out:
# (71, 31)

# %%
X_train_var;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-092bb58408dc> in <module>
# ----> 1 X_train_var;
#
# NameError: name 'X_train_var' is not defined

# %%
X_test_var.shape
# Out:
# (9, 31)

# %%
X_test_var
# Out:
#       Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 12   345          3            5            3       1976          1976
# 15   386          3            8            5       2004          2005
# 29   604          3            7            5       2004          2005
# 30   615          3            4            6       1972          1972
# 44   960          3            7            5       1999          1999
# 57  1087          3            4            5       1973          1973
# 64  1161          3            6            5       1978          1978
# 67  1237          3            7            5       2003          2003
# 74  1359          3            6            5       2000          2000
#
#     MasVnrArea  ExterQual  ExterCond  BsmtQual       ...        OpenPorchSF  \
# 12         0.0          3          3         4       ...                  0
# 15        16.0          4          3         4       ...                 20
# 29         0.0          4          3         4       ...                172
# 30         0.0          3          3         4       ...                 24
# 44         0.0          4          3         4       ...                 44
# 57         0.0          3          3         3       ...                 96
# 64         0.0          3          3         4       ...                  0
# 67       106.0          4          3         4       ...                 27
# 74       216.0          4          3         4       ...                 32
#
#     EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  YrSold  \
# 12              0          0            0         0       0        0    2010
# 15              0          0          144         0       0        0    2010
# 29              0          0            0         0       0        0    2010
# 30              0          0            0         0       0        0    2010
# 44              0          0            0         0       0        0    2010
# 57              0          0            0         0       0        0    2010
# 64              0          0            0         0       0        0    2010
# 67              0          0            0         0       0        0    2010
# 74              0          0            0         0       0        0    2010
#
#     SalePrice  FixedPredicted
# 12      85000    98625.966241
# 15     192000   168835.496033
# 29     151000   158925.695435
# 30      75500    71617.931395
# 44     155000   162188.022790
# 57      83500    95497.415843
# 64     146000   146085.379198
# 67     175500   180150.508227
# 74     177500   175215.483979
#
# [9 rows x 31 columns]

# %%
y_test_var.shape = (9,1)

# %%
X_test_var.columns
# Out:
# Index(['Id', 'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'BsmtUnfSF', 'HeatingQC', 'CentralAir', 'BsmtHalfBath',
#        'HalfBath', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'MiscVal', 'YrSold', 'SalePrice',
#        'FixedPredicted'],
#       dtype='object')

# %%
X_test_var.columns
# Out:
# Index(['Id', 'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'BsmtUnfSF', 'HeatingQC', 'CentralAir', 'BsmtHalfBath',
#        'HalfBath', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'MiscVal', 'YrSold', 'SalePrice',
#        'FixedPredicted'],
#       dtype='object')

# %%
y_test_var.shape
# Out:
# (9, 1)

# %%
y_test_var
# Out:
# array([[13625.96624145],
#        [23164.50396669],
#        [ 7925.69543476],
#        [ 3882.06860525],
#        [ 7188.02279038],
#        [11997.41584311],
#        [   85.37919761],
#        [ 4650.50822675],
#        [ 2284.51602103]])

# %%
y_train_var.shape = (71,1)

# %%
y_train_var.shape
# Out:
# (71, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lrvar = linear_model.LinearRegression()


#  Model fitting
X = X_train_var
y = y_train_var

# %%
lrvar.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Intercept: \n', lrvar.intercept_)
print('Coefficients: \n', lrvar.coef_)
#print_model = varmodel.score
#print(print_model)
# Out:
# Intercept:
#  [-383919.39201141]
# Coefficients:
#  [[ 4.15424658e+00 -1.18063564e-07 -8.85109820e+02 -1.40005393e+03
#   -1.55283807e+02 -8.14676282e+01  7.89222582e-01  5.55126087e+03
#    3.51345642e+01 -7.58369697e+02 -9.40131219e+03  2.41166766e+00
#    6.26491694e+02  1.56457072e+04  5.06420133e+03  7.02363292e+02
#    8.23519939e+02  1.03519215e+02  1.24145341e+04 -1.46342789e+04
#   -1.43481866e+01 -6.84544585e+00 -3.21549685e+01  1.45519152e-11
#   -1.93615778e+02 -1.81898940e-12  0.00000000e+00  0.00000000e+00
#    4.24527988e+02 -1.28489482e-02  1.38566696e-01]]

# %%
Var_predictions = lrvar.predict(X_test_var)

# %%
print(Var_predictions)
print(RHV_test.Residuals.values)
# Out:
# [[  4313.95984449]
#  [-17031.12344454]
#  [ 11703.25426134]
#  [  7304.67726059]
#  [ 14499.13487233]
#  [  6857.45376123]
#  [ 12149.90111067]
#  [ 18749.12508857]
#  [ 19263.46293395]]
# [[13625.96624145]
#  [23164.50396669]
#  [ 7925.69543476]
#  [ 3882.06860525]
#  [ 7188.02279038]
#  [11997.41584311]
#  [   85.37919761]
#  [ 4650.50822675]
#  [ 2284.51602103]]

# %%
### 2nd and 3rd values - have renovations:  value of variable features + value of renovations at the remodel year
### residuals is value on year 2010
pred_temp_df = pd.DataFrame((abs(Var_predictions) * 5)/10)

# %%
pred_temp_df.values
# Out:
# array([[ 5864.45974034],
#        [13028.15693462],
#        [ 5965.90656969],
#        [ 6336.20850646],
#        [ 7755.22805645],
#        [ 4149.83524311],
#        [ 3571.00256052],
#        [ 9324.21264224],
#        [ 8395.27123686]])

# %%
#RHV_test['Var_Predicted'] = pred_temp_df

# %%
#RHV_test

# %%
pred_temp_df
# Out:
#               0
# 0   5864.459740
# 1  13028.156935
# 2   5965.906570
# 3   6336.208506
# 4   7755.228056
# 5   4149.835243
# 6   3571.002561
# 7   9324.212642
# 8   8395.271237

# %%
#RHV_test['Depreciated_pred'] = 
VDV = pd.merge(RHV_test, temp_df, on='Id')

# %%
print(Var_predictions)
print('/n')
RHV_test.Residuals.values
# Out:
# [[ 11728.91948067]
#  [-26056.31386924]
#  [ 11931.81313937]
#  [ 12672.41701292]
#  [ 15510.4561129 ]
#  [  8299.67048623]
#  [  7142.00512105]
#  [ 18648.42528449]
#  [ 16790.54247372]]
# /n
# array([[13625.96624146],
#        [23164.50396669],
#        [ 7925.69543476],
#        [ 3882.06860525],
#        [ 7188.02279038],
#        [11997.41584311],
#        [   85.37919761],
#        [ 4650.50822675],
#        [ 2284.51602103]])

# %%
#print("R^2 is: \n", lrvar.score(X_test_var, pred_temp_df.values))


#print('RMSE is: ')
#mean_squared_error(y_test_var, pred_temp_df.values)

# %%
#Running On the whole train package
Full_Train_Var_predictions = lrvar.predict(X_train_var)

# %%
Full_Train_Var_predictions
# Out:
# array([[-2.80366585e+03],
#        [ 6.88516889e+03],
#        [ 5.17307238e+03],
#        [ 1.25593771e+04],
#        [ 7.31699619e+03],
#        [ 4.61765432e+03],
#        [ 1.06834623e+04],
#        [ 2.89617494e+03],
#        [ 1.72250277e+04],
#        [ 4.70427121e+03],
#        [ 7.22628276e+03],
#        [ 6.33288126e+03],
#        [ 1.51896732e+04],
#        [ 5.88880583e+02],
#        [ 4.23697983e+03],
#        [ 1.44221270e+03],
#        [ 7.43624294e+03],
#        [ 1.81416099e+04],
#        [ 4.43981095e+03],
#        [ 2.18626789e+04],
#        [ 7.50329139e+02],
#        [ 5.39368488e+03],
#        [ 4.73302471e+03],
#        [ 1.12523226e+04],
#        [ 1.53738672e+04],
#        [ 1.26732217e+04],
#        [ 1.39593663e+03],
#        [ 1.34119349e+04],
#        [ 6.94946101e+03],
#        [ 1.14684455e+04],
#        [ 4.05411027e+03],
#        [ 1.06613267e+04],
#        [ 8.59646498e+03],
#        [ 8.17786980e+03],
#        [ 6.04020089e+03],
#        [ 6.17005282e+03],
#        [ 2.34777087e+03],
#        [ 1.78965759e+04],
#        [ 1.27994232e+04],
#        [ 4.14348261e+02],
#        [ 7.46189965e+03],
#        [ 1.74373140e+04],
#        [ 1.20086453e+04],
#        [ 9.06268787e+03],
#        [ 1.57002147e+04],
#        [ 5.65041856e+03],
#        [ 1.33798773e+04],
#        [ 5.48837035e+03],
#        [ 8.63684019e+03],
#        [ 1.48461508e+04],
#        [ 9.52779177e+03],
#        [ 5.22558123e+03],
#        [ 8.07800969e+03],
#        [ 1.60222424e+04],
#        [ 1.26619915e+04],
#        [ 1.32913841e+04],
#        [ 1.08119116e+04],
#        [ 2.02545132e+04],
#        [ 4.85388638e+03],
#        [ 1.20037174e+04],
#        [ 2.12723015e+04],
#        [ 1.66999499e+04],
#        [ 5.37845680e+03],
#        [ 1.03173383e+04],
#        [ 1.46349056e+04],
#        [ 6.61541091e+03],
#        [ 1.11661096e+04],
#        [ 1.46175488e+04],
#        [-2.14437023e-07],
#        [ 2.41958254e+04],
#        [ 8.09031450e+02]])

# %%
pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[np.mean])
# Out:
#                        mean                                               \
#                   SalePrice
# YrSold                 2006           2007           2008           2009
# Neighborhood
# 2.5           176457.142857  161159.375000  183446.153846  167860.461538
# 5.0           199545.357143  201579.367347  187344.565217  194906.661017
# 7.0           123466.666667  105850.000000   98000.000000   88400.000000
# 10.0          179689.585062  185905.530769  175798.539095  178254.298851
#
#
#
# YrSold                 2010
# Neighborhood
# 2.5           166950.000000
# 5.0           197952.631579
# 7.0            81333.333333
# 10.0          176986.530201

# %%
#plt.style.use('fivethirtyeight')
ax = pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[np.median]).plot(kind='bar', rot=65, figsize=(16,8), width=.8)
ax.set_xlabel('Neighborhood', fontsize=14)
ax.set_title('Median Sales price of Homes Sold by Year & neighborhood', fontsize=14)
ax.legend(labels=['2006','2007','2008','2009','2010']);

# %%
#plt.style.use('fivethirtyeight')
ax = pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[len]).plot(kind='bar', rot=65, figsize=(16,8), width=.8)
ax.set_xlabel('Neighborhood', fontsize=14)
ax.set_title('Number of Homes Sold by Year', fontsize=14)
ax.legend(labels=['2006','2007','2008','2009','2010']);

# %%
house.MiscFeature.unique()
# Out:
# array(['None', 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
house[house.MiscFeature=='Othr'].MiscVal
# Out:
# 705    3500
# 873       0
# Name: MiscVal, dtype: int64

# %%
house.MiscVal.unique()
# Out:
# array([    0,   700,   350,   500,   400,   480,   450, 15500,  1200,
#          800,  2000,   600,  3500,  1300,    54,   620,   560,  1400,
#         8300,  1150,  2500])

# %%
house_var = house[house_var_col]
house_var.head(3)
# Out:
#    Id  Neighborhood  Utilities  OverallQual  OverallCond  YearBuilt  \
# 0   1           5.0          3            7            5       2003
# 1   2           2.5          3            6            8       1976
# 2   3           5.0          3            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior2nd    ...     PoolArea  PoolQC  \
# 0          2003     Gable  CompShg     VinylSd    ...            0       0
# 1          1976     Gable  CompShg     MetalSd    ...            0       0
# 2          2002     Gable  CompShg     VinylSd    ...            0       0
#
#    Fence  MiscFeature  MiscVal  MoSold YrSold  SaleType SaleCondition  \
# 0   None         None        0       2   2008        WD        Normal
# 1   None         None        0       5   2007        WD        Normal
# 2   None         None        0       9   2008        WD        Normal
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
#
# [3 rows x 46 columns]

# %% [markdown]
#  TO DO
#
#  remove abnormal sale =  SaleCondition = Abnormal
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %%
house_var_price_columns = ['YearBuilt','YearRemodAdd' ,'MoSold', 'YrSold','SaleType','SalePrice','SaleCondition']

# %%
house_var_price = house_var[house_var_price_columns]

# %%
house_var_price.YrSold.min()    ## 2006 -2010
# Out:
# 2006

# %%
house_var_price.YearBuilt.max()   #....1872 - 2010
# Out:
# 2010

# %%
house_var_price.YearBuilt.max()   #....1872 - 2010
# Out:
# 2010

# %%
house_var_price.YearRemodAdd.max()   # 1950 -2010
# Out:
# 2010

# %%
house_var_solver = house_var[house_var['YearBuilt'] !=  house_var['YearRemodAdd']]

# %%
house_var_solver.shape
# Out:
# (696, 46)

# %%
house_var_test = house_var[house_var['YrSold'] ==  house_var['YearRemodAdd']]

# %%
#house_var_test

# %%
house_var_train = house_var[house_var['YrSold'] == 2010]

# %%
house_var_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 16 to 1458
# Data columns (total 46 columns):
# Id               175 non-null int64
# Neighborhood     175 non-null float64
# Utilities        175 non-null int64
# OverallQual      175 non-null int64
# OverallCond      175 non-null int64
# YearBuilt        175 non-null int64
# YearRemodAdd     175 non-null int64
# RoofStyle        175 non-null object
# RoofMatl         175 non-null object
# Exterior2nd      175 non-null object
# MasVnrType       175 non-null object
# MasVnrArea       175 non-null float64
# ExterQual        175 non-null int64
# ExterCond        175 non-null int64
# BsmtQual         175 non-null int64
# BsmtCond         175 non-null int64
# BsmtFinType2     175 non-null object
# BsmtUnfSF        175 non-null int64
# Heating          175 non-null object
# HeatingQC        175 non-null int64
# CentralAir       175 non-null int64
# Electrical       175 non-null object
# BsmtHalfBath     175 non-null int64
# HalfBath         175 non-null int64
# KitchenQual      175 non-null int64
# TotRmsAbvGrd     175 non-null int64
# Functional       175 non-null int64
# FireplaceQu      175 non-null int64
# GarageQual       175 non-null int64
# GarageCond       175 non-null int64
# PavedDrive       175 non-null object
# WoodDeckSF       175 non-null int64
# OpenPorchSF      175 non-null int64
# EnclosedPorch    175 non-null int64
# 3SsnPorch        175 non-null int64
# ScreenPorch      175 non-null int64
# PoolArea         175 non-null int64
# PoolQC           175 non-null int64
# Fence            175 non-null object
# MiscFeature      175 non-null object
# MiscVal          175 non-null int64
# MoSold           175 non-null int64
# YrSold           175 non-null int64
# SaleType         175 non-null object
# SaleCondition    175 non-null object
# SalePrice        175 non-null int64
# dtypes: float64(2), int64(32), object(12)
# memory usage: 64.3+ KB

# %%
##house_var_train

# %%
dum_MasVnrType = house_var_train[['MasVnrType']].copy()
dum_MasVnrType.head(10)
# Out:
#    MasVnrType
# 16    BrkFace
# 24       None
# 26       None
# 27      Stone
# 33       None
# 38       None
# 45    BrkFace
# 52       None
# 63       None
# 66    BrkFace

# %%
dum_Mas = pd.get_dummies(dum_MasVnrType)
dum_Mas.head()
# Out:
#     MasVnrType_BrkCmn  MasVnrType_BrkFace  MasVnrType_None  MasVnrType_Stone
# 16                  0                   1                0                 0
# 24                  0                   0                1                 0
# 26                  0                   0                1                 0
# 27                  0                   0                0                 1
# 33                  0                   0                1                 0

# %%
for col in dum_Mas.columns:
    print(col)
    print(dum_Mas[col].value_counts())
    print('\n')
# Out:
# MasVnrType_BrkCmn
# 0    174
# 1      1
# Name: MasVnrType_BrkCmn, dtype: int64
#
#
# MasVnrType_BrkFace
# 0    122
# 1     53
# Name: MasVnrType_BrkFace, dtype: int64
#
#
# MasVnrType_None
# 1    105
# 0     70
# Name: MasVnrType_None, dtype: int64
#
#
# MasVnrType_Stone
# 0    159
# 1     16
# Name: MasVnrType_Stone, dtype: int64

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. What property characteristics predict an "abnormal" sale?
#
# ---
#
# The `SaleCondition` feature indicates the circumstances of the house sale. From the data file, we can see that the possibilities are:
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# One of the executives at your company has an "in" with higher-ups at the major regional bank. His friends at the bank have made him a proposal: if he can reliably indicate what features, if any, predict "abnormal" sales (foreclosures, short sales, etc.), then in return the bank will give him first dibs on the pre-auction purchase of those properties (at a dirt-cheap price).
#
# He has tasked you with determining (and adequately validating) which features of a property predict this type of sale.
#
# ---
#
# **Your task:**
# 1. Determine which features predict the `Abnorml` category in the `SaleCondition` feature.
# - Justify your results.
#
# This is a challenging task that tests your ability to perform classification analysis in the face of severe class imbalance. You may find that simply running a classifier on the full dataset to predict the category ends up useless: when there is bad class imbalance classifiers often tend to simply guess the majority class.
#
# It is up to you to determine how you will tackle this problem. I recommend doing some research to find out how others have dealt with the problem in the past. Make sure to justify your solution. Don't worry about it being "the best" solution, but be rigorous.
#
# Be sure to indicate which features are predictive (if any) and whether they are positive or negative predictors of abnormal sales.

# %%
# A:  

#Feature selection using SelectFromModel and LassoCV — scikit-learn 0.20.3 documentation#
#https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_boston.html
    #sphx-glr-auto-examples-feature-selection-plot-select-from-model-boston-py
