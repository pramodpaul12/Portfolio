# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 3
#
# ### Regression and Classification with the Ames Housing Data
#
# ---
#
# You have just joined a new "full stack" real estate company in Ames, Iowa. The strategy of the firm is two-fold:
# - Own the entire process from the purchase of the land all the way to sale of the house, and anything in between.
# - Use statistical analysis to optimize investment and maximize return.
#
# The company is still small, and though investment is substantial the short-term goals of the company are more oriented towards purchasing existing houses and flipping them as opposed to constructing entirely new houses. That being said, the company has access to a large construction workforce operating at rock-bottom prices.
#
# This project uses the [Ames housing data recently made available on kaggle](https://www.kaggle.com/c/house-prices-advanced-regression-techniques).

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use(style = "ggplot")
plt.rcParams['figure.figsize'] = [10,6]

print(__doc__)

import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import load_boston
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
import pandas as pd


sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline


#import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification



from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn import linear_model
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Estimating the value of homes from fixed characteristics.
#
# ---
#
# Your superiors have outlined this year's strategy for the company:
# 1. Develop an algorithm to reliably estimate the value of residential houses based on #fixed characteristics.
# 2. Identify characteristics of houses that the company can cost-effectively change/renovate with their construction team.
# 3. Evaluate the mean dollar value of different renovations.
#
# Then we can use that to buy houses that are likely to sell for more than the cost of the purchase plus renovations.
#
# Your first job is to tackle #1. You have a dataset of housing sale data with a huge amount of features identifying different aspects of the house. The full description of the data features can be found in a separate file:
#
#     housing.csv
#     data_description.txt
#
# You need to build a reliable estimator for the price of the house given characteristics of the house that cannot be renovated. Some examples include:
# - The neighborhood
# - Square feet
# - Bedrooms, bathrooms
# - Basement and garage space
#
# and many more.
#
# Some examples of things that **ARE renovate-able:**
# - Roof and exterior features
# - "Quality" metrics, such as kitchen quality
# - "Condition" metrics, such as condition of garage
# - Heating and electrical components
#
# and generally anything you deem can be modified without having to undergo major construction on the house.
#
# ---
#
# **Your goals:**
# 1. Perform any cleaning, feature engineering, and EDA you deem necessary.
# - Be sure to remove any houses that are not residential from the dataset.
# - Identify **fixed** features that can predict price.
# - Train a model on pre-2010 data and evaluate its performance on the 2010 houses.
# - Characterize your model. How well does it perform? What are the best estimates of price?
#
# > **Note:** The EDA and feature engineering component to this project is not trivial! Be sure to always think critically and creatively. Justify your actions! Use the data description file!

# %%
## EDA
# Load the data
house = pd.read_csv('./housing.csv')

# %%
house.shape
# Out:
# (1460, 81)

# %%
# salesprice skewness
#sns.distplot([house.SalePrice], hist = True, kde = True)

# %%
#plt.hist(house.SalePrice,color = 'Blue' )

# %%
#house.kurtosis()
#house.skew(axis = 0, skipna = True)
#house.SalePrice.describe()

# %%
house.SalePrice.skew()     ### positive skew
# Out:
# 1.8828757597682129

# %%
## do target log transform...np.log..better linearity
##at end  reverse..np.exp
target = np.log(house.SalePrice)
#plt.hist(target,color = 'Blue' )
#target.skew()  #### value closer to zero indicates better skew with log values...

# %%
numeric_features = house.select_dtypes(include=[np.number])

# %%
# displays the correlation between the features columns and the target.
corr = numeric_features.corr()
corr['SalePrice'].sort_values(ascending=False)[:20]
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# Name: SalePrice, dtype: float64

# %%
corr['SalePrice'].sort_values(ascending=False)[-20:]
# Out:
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# Condition2       0.051079
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# Condition1      -0.013506
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# Neighborhood    -0.034527
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
house.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
OverallQualPivot = house.pivot_table(values = "SalePrice", index ='OverallQual', aggfunc = np.median)
#OverallQualPivot

# %%
plt.plot(OverallQualPivot, color = 'Blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
#plt.show()
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#to generate some scatter plots and visualize the relationship between the Ground Living Area(GrLivArea) and SalePrice
plt.scatter(x= house['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area sqft')
plt.show()

# %%
# do the same for GarageArea.
plt.scatter(x=house['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %%
#house.GarageArea.unique()   #### has outliers..1200 -1400 sqft

# %%
#house.isnull().sum()   ### look at null values

# %%
cols_with_na = pd.DataFrame(house.isnull().sum().sort_values(ascending=False)[:25])
cols_with_na.columns = ['NA Count']
cols_with_na.index.name = 'Feature'

cols_with_na
# Out:
#               NA Count
# Feature
# PoolQC            1453
# MiscFeature       1406
# Alley             1369
# Fence             1179
# FireplaceQu        690
# LotFrontage        259
# GarageCond          81
# GarageType          81
# GarageYrBlt         81
# GarageFinish        81
# GarageQual          81
# BsmtExposure        38
# BsmtFinType2        38
# BsmtFinType1        37
# BsmtCond            37
# BsmtQual            37
# MasVnrArea           8
# MasVnrType           8
# Electrical           1
# Utilities            0
# YearRemodAdd         0
# MSSubClass           0
# Foundation           0
# ExterCond            0
# ExterQual            0

# %%
house.MiscFeature.unique()   #### MiscFeature with dollar values of renvoations, Tennis court
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
#CLEANING NAN VALUES
#1  Non numericfeatures where NaN values have meaning e.g. no pool etc.
cols_fill_na = ['PoolQC','MiscFeature','Alley','Fence','MasVnrType','FireplaceQu',
               'GarageQual','GarageCond','GarageFinish','GarageType',
               'BsmtExposure','BsmtCond','BsmtQual','BsmtFinType1','BsmtFinType2']

# replace 'NaN' with 'None' in these columns
for col in cols_fill_na:
    house[col].fillna('None',inplace=True)

# %%
#GarageYrBlt nans: no garage. replace with property YearBuilt.
#(more appropriate than 0, which is ~2000 away from all other values)
house.loc[house.GarageYrBlt.isnull(),'GarageYrBlt'] = house.loc[house.GarageYrBlt.isnull(),'YearBuilt']


#No masonry veneer - fill area with 0
house.MasVnrArea.fillna(0,inplace=True)

#No basement - fill areas/counts with 0    
house.BsmtFullBath.fillna(0,inplace=True)
house.BsmtHalfBath.fillna(0,inplace=True)
house.BsmtFinSF1.fillna(0,inplace=True)
house.BsmtFinSF2.fillna(0,inplace=True)
house.BsmtUnfSF.fillna(0,inplace=True)
house.TotalBsmtSF.fillna(0,inplace=True)

#No garage - fill areas/counts with 0
house.GarageArea.fillna(0,inplace=True)
house.GarageCars.fillna(0,inplace=True)

house[cols_fill_na].head(5)
# Out:
#   PoolQC MiscFeature Alley Fence MasVnrType FireplaceQu GarageQual GarageCond  \
# 0   None        None  None  None    BrkFace        None         TA         TA
# 1   None        None  None  None       None          TA         TA         TA
# 2   None        None  None  None    BrkFace          TA         TA         TA
# 3   None        None  None  None       None          Gd         TA         TA
# 4   None        None  None  None    BrkFace          TA         TA         TA
#
#   GarageFinish GarageType BsmtExposure BsmtCond BsmtQual BsmtFinType1  \
# 0          RFn     Attchd           No       TA       Gd          GLQ
# 1          RFn     Attchd           Gd       TA       Gd          ALQ
# 2          RFn     Attchd           Mn       TA       Gd          GLQ
# 3          Unf     Detchd           No       Gd       TA          ALQ
# 4          RFn     Attchd           Av       TA       Gd          GLQ
#
#   BsmtFinType2
# 0          Unf
# 1          Unf
# 2          Unf
# 3          Unf
# 4          Unf

# %%
# LotFrontage NAN values
house.LotFrontage.fillna(0,inplace=True)

# %%
house.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
house.OverallQual.unique(),
# Out:
# (array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2]),)

# %%
house.OverallCond.unique()
# Out:
# array([5, 8, 6, 7, 4, 2, 3, 9, 1])

# %%
house.Neighborhood.unique()
# Out:
# array([ 5. ,  2.5, 10. ,  7. ])

# %%
# flood plain rating
house['Neighborhood'].replace({'CollgCr':5, 'Veenker':2.5, 'Crawfor' :10, 'NoRidge':10, 'Mitchel': 2.5, 'Somerst':10,
       'NWAmes' : 10, 'OldTown': 10, 'BrkSide':10, 'Sawyer':10, 'NridgHt':10, 'NAmes':10,
       'SawyerW': 10 , 'IDOTRR': 10, 'MeadowV': 7, 'Edwards':10, 'Timber':10, 'Gilbert':5,
       'StoneBr':10, 'ClearCr':10, 'NPkVill':10, 'Blmngtn':10, 'BrDale':10, 'SWISU':10,
       'Blueste':10}, inplace=True)

# %% [markdown]
# Artery	Adjacent to arterial street                           7
#        Feedr	Adjacent to feeder street	                  6
#        Norm	Normal	                                          5
#        RRNn	Within 200' of North-South Railroad        1
#        RRAn	Adjacent to North-South Railroad           1
#        PosN	Near positive off-site feature--park, greenbelt, etc.   10
#        PosA	Adjacent to postive off-site feature                     10
#        RRNe	Within 200' of East-West Railroad                   1
#        RRAe	Adjacent to East-West Railroad                       1
#
#
#        An arterial road or arterial thoroughfare is a high-capacity urban road.
#        The term feeder road can refer to one of several related types of thoroughfare: A secondary road which "feeds" traffic to main highways and freeways. A frontage road, that is, a road which runs parallel with high-speed roads, allowing easier access to local amenities.

# %%
house.Condition1.unique()
# Out:
# array(['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA',
#        'RRNe'], dtype=object)

# %%
house['Condition1'].replace({'Norm':5, 'Feedr':6, 'PosN':10, 'Artery':7, 'RRAe':1, 'RRNn':1, 'RRAn':1, 'PosA':10,
       'RRNe':1}, inplace=True)

# Norm - 10
#  RR - 3

# %%
house.Condition2.unique()
# Out:
# array(['Norm', 'Artery', 'RRNn', 'Feedr', 'PosN', 'PosA', 'RRAn', 'RRAe'],
#       dtype=object)

# %%
house['Condition2'].replace({'Norm':5, 'Feedr':6, 'PosN':10, 'Artery':7, 'RRAe':1, 'RRNn':1, 'RRAn':1, 'PosA':10,
       'RRNe':1}, inplace=True)
#

# %%
# convert some categorical values to numeric scales

#Excellent, Good, Typical, Fair, Poor, None: Convert to 0-5 scale
cols_Ex_None = ['ExterQual','ExterCond','BsmtQual','BsmtCond',
             'HeatingQC','KitchenQual','FireplaceQu','GarageQual',
            'GarageCond','PoolQC']

dict_Ex_None = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'None':0}

for col in cols_Ex_None:
    house[col].replace(dict_Ex_None, inplace=True)

#house[cols_Ex_None].head(5)   

# Remaining columns
house['BsmtExposure'].replace({'Gd':4,'Av':3,'Mn':2,'No':1,'None':0}, inplace=True)

house['CentralAir'].replace({'Y':1,'N':0}, inplace=True)

house['Functional'].replace({'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,'Maj2':2,'Sev':1,'Sal':0}, inplace=True)

house['GarageFinish'].replace({'Fin':3,'RFn':2,'Unf':1,'None':0}, inplace=True)

house['LotShape'].replace({'Reg':3,'IR1':2,'IR2':1,'IR3':0}, inplace=True)

house['Utilities'].replace({'AllPub':3,'NoSewr':2,'NoSeWa':1,'ELO':0}, inplace=True)

house['LandSlope'].replace({'Gtl':2,'Mod':1,'Sev':0}, inplace=True)

# %%
house[cols_Ex_None].head(5)
# Out:
#    ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  KitchenQual  \
# 0          4          3         4         3          5            4
# 1          3          3         4         3          5            3
# 2          4          3         4         3          5            4
# 3          3          3         3         4          4            4
# 4          4          3         4         3          5            4
#
#    FireplaceQu  GarageQual  GarageCond  PoolQC
# 0            0           3           3       0
# 1            3           3           3       0
# 2            3           3           3       0
# 3            4           3           3       0
# 4            3           3           3       0

# %%
#Business question:  Develop an algorithm to reliably estimate the value of residential houses 
###based on #fixed characteristics.  >>> Call it  value_fixed 
### 1) Plan  - this step
# 2)Understand the business question
# 3) read the data dictionary
# 4) What all are fixed characteristics of the house that can predict price
#The neighborhood, Square feet, Bedrooms, bathrooms, Basement and garage space
#  renovatable features:  Identify fixed features that can predict price.
#Roof and exterior features
#"Quality" metrics, such as kitchen quality
#"Condition" metrics, such as condition of garage
#Heating and electrical components
#and generally anything you deem can be modified without #having to undergo major construction on the house.
#####  Use Lasso with cross validation to get the 10 fixed variables

### remove any non - residential   -  remove all rows based on non residential from MSZoning column

# %%
# consider the non-numeric features 
categoricals = house.select_dtypes(exclude=[np.number])
#print(categoricals.describe())

# %%
#to remove skew
#  keep only residential houses     
# remove all plots > 4000 sqft lot area
# remove all houses with GRLIVAREA > 1500
# remove all houses with salecondition not normal

# %%
r_house = house[house.MSZoning != 'C (all)']
r_house.MSZoning.value_counts()
# Out:
# RL    1151
# RM     218
# FV      65
# RH      16
# Name: MSZoning, dtype: int64

# %%
r_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1450 non-null int64
# MSSubClass       1450 non-null int64
# MSZoning         1450 non-null object
# LotFrontage      1450 non-null float64
# LotArea          1450 non-null int64
# Street           1450 non-null object
# Alley            1450 non-null object
# LotShape         1450 non-null int64
# LandContour      1450 non-null object
# Utilities        1450 non-null int64
# LotConfig        1450 non-null object
# LandSlope        1450 non-null int64
# Neighborhood     1450 non-null object
# Condition1       1450 non-null object
# Condition2       1450 non-null object
# BldgType         1450 non-null object
# HouseStyle       1450 non-null object
# OverallQual      1450 non-null int64
# OverallCond      1450 non-null int64
# YearBuilt        1450 non-null int64
# YearRemodAdd     1450 non-null int64
# RoofStyle        1450 non-null object
# RoofMatl         1450 non-null object
# Exterior1st      1450 non-null object
# Exterior2nd      1450 non-null object
# MasVnrType       1450 non-null object
# MasVnrArea       1450 non-null float64
# ExterQual        1450 non-null int64
# ExterCond        1450 non-null int64
# Foundation       1450 non-null object
# BsmtQual         1450 non-null int64
# BsmtCond         1450 non-null int64
# BsmtExposure     1450 non-null int64
# BsmtFinType1     1450 non-null object
# BsmtFinSF1       1450 non-null int64
# BsmtFinType2     1450 non-null object
# BsmtFinSF2       1450 non-null int64
# BsmtUnfSF        1450 non-null int64
# TotalBsmtSF      1450 non-null int64
# Heating          1450 non-null object
# HeatingQC        1450 non-null int64
# CentralAir       1450 non-null int64
# Electrical       1449 non-null object
# 1stFlrSF         1450 non-null int64
# 2ndFlrSF         1450 non-null int64
# LowQualFinSF     1450 non-null int64
# GrLivArea        1450 non-null int64
# BsmtFullBath     1450 non-null int64
# BsmtHalfBath     1450 non-null int64
# FullBath         1450 non-null int64
# HalfBath         1450 non-null int64
# BedroomAbvGr     1450 non-null int64
# KitchenAbvGr     1450 non-null int64
# KitchenQual      1450 non-null int64
# TotRmsAbvGrd     1450 non-null int64
# Functional       1450 non-null int64
# Fireplaces       1450 non-null int64
# FireplaceQu      1450 non-null int64
# GarageType       1450 non-null object
# GarageYrBlt      1450 non-null float64
# GarageFinish     1450 non-null int64
# GarageCars       1450 non-null int64
# GarageArea       1450 non-null int64
# GarageQual       1450 non-null int64
# GarageCond       1450 non-null int64
# PavedDrive       1450 non-null object
# WoodDeckSF       1450 non-null int64
# OpenPorchSF      1450 non-null int64
# EnclosedPorch    1450 non-null int64
# 3SsnPorch        1450 non-null int64
# ScreenPorch      1450 non-null int64
# PoolArea         1450 non-null int64
# PoolQC           1450 non-null int64
# Fence            1450 non-null object
# MiscFeature      1450 non-null object
# MiscVal          1450 non-null int64
# MoSold           1450 non-null int64
# YrSold           1450 non-null int64
# SaleType         1450 non-null object
# SaleCondition    1450 non-null object
# SalePrice        1450 non-null int64
# dtypes: float64(3), int64(52), object(26)
# memory usage: 928.9+ KB

# %%
r_house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea     LotShape  \
# count  1450.000000  1450.000000   1450.00000    1450.000000  1450.000000
# mean    731.364138    56.903448     57.54000   10523.831724     2.589655
# std     421.554345    42.265033     34.71992   10012.185355     0.583205
# min       1.000000    20.000000      0.00000    1300.000000     0.000000
# 25%     366.250000    20.000000     41.25000    7544.500000     2.000000
# 50%     731.500000    50.000000     63.00000    9496.000000     3.000000
# 75%    1096.750000    70.000000     79.00000   11613.500000     3.000000
# max    1460.000000   190.000000    313.00000  215245.000000     3.000000
#
#          Utilities    LandSlope  Neighborhood   Condition1   Condition2  \
# count  1450.000000  1450.000000   1450.000000  1450.000000  1450.000000
# mean      2.998621     1.939310      8.864828     5.092414     5.005517
# std       0.052523     0.273842      2.257494     1.063095     0.323836
# min       1.000000     0.000000      2.500000     1.000000     1.000000
# 25%       3.000000     2.000000     10.000000     5.000000     5.000000
# 50%       3.000000     2.000000     10.000000     5.000000     5.000000
# 75%       3.000000     2.000000     10.000000     5.000000     5.000000
# max       3.000000     2.000000     10.000000    10.000000    10.000000
#
#            ...        OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count      ...        1450.000000    1450.000000  1450.000000  1450.000000
# mean       ...          46.537931      21.536552     3.433103    15.096552
# std        ...          65.222761      60.838826    29.416948    55.893399
# min        ...           0.000000       0.000000     0.000000     0.000000
# 25%        ...           0.000000       0.000000     0.000000     0.000000
# 50%        ...          25.000000       0.000000     0.000000     0.000000
# 75%        ...          68.000000       0.000000     0.000000     0.000000
# max        ...         547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       PoolQC       MiscVal       MoSold       YrSold  \
# count  1450.000000  1450.000000   1450.000000  1450.000000  1450.000000
# mean      2.777931     0.017931     43.365517     6.312414  2007.812414
# std      40.315051     0.269874    497.636495     2.698244     1.326321
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     738.000000     5.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1450.000000
# mean   181654.942069
# std     79176.485241
# min     37900.000000
# 25%    130000.000000
# 50%    163945.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 58 columns]

# %%
r_house.shape
# Out:
# (1450, 81)

# %%
r_house_filt_lux = r_house[(r_house.LotArea > 4000) & (r_house.SalePrice > 200000)]
#& house.SaleCondition == 'normal']

# %%
r_house_filt_lux.shape
# Out:
# (422, 81)

# %%
#r_house_filt_lux.LotArea.value_counts()

# %%
#r_house_filt_lux.SalePrice.unique()

# %%
#r_house_filt_lux

# %%
#r_house_filt1 = r_house_filt[r_house_filt.GrLivArea < 1500]

# %%
r_house_filt_lux.shape
# Out:
# (422, 81)

# %%
r_house_filt_lux.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 0    1          60       RL         65.0     8450   Pave  None         3
# 2    3          60       RL         68.0    11250   Pave  None         2
# 4    5          60       RL         84.0    14260   Pave  None         2
# 6    7          20       RL         75.0    10084   Pave  None         3
# 11  12          60       RL         85.0    11924   Pave  None         2
#
#    LandContour  Utilities    ...     PoolArea  PoolQC  Fence  MiscFeature  \
# 0          Lvl          3    ...            0       0   None         None
# 2          Lvl          3    ...            0       0   None         None
# 4          Lvl          3    ...            0       0   None         None
# 6          Lvl          3    ...            0       0   None         None
# 11         Lvl          3    ...            0       0   None         None
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         0      2   2008        WD         Normal     208500
# 2         0      9   2008        WD         Normal     223500
# 4         0     12   2008        WD         Normal     250000
# 6         0      8   2007        WD         Normal     307000
# 11        0      7   2006       New        Partial     345000
#
# [5 rows x 81 columns]

# %%
r_house_filt_lux.SaleCondition.value_counts()
# Out:
# Normal     315
# Partial     87
# Abnorml     13
# Alloca       4
# Family       3
# Name: SaleCondition, dtype: int64

# %%
r_house_final_lux = r_house_filt_lux[r_house_filt_lux['SaleCondition'] == 'Normal']

# %%
r_house_final_lux.shape
# Out:
# (315, 81)

# %%
r_house_final_lux
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None         3
# 2        3          60       RL         68.0    11250   Pave  None         2
# 4        5          60       RL         84.0    14260   Pave  None         2
# 6        7          20       RL         75.0    10084   Pave  None         3
# 22      23          20       RL         75.0     9742   Pave  None         3
# 25      26          20       RL        110.0    14230   Pave  None         3
# 27      28          20       RL         98.0    11478   Pave  None         3
# 28      29          20       RL         47.0    16321   Pave  None         2
# 34      35         120       RL         60.0     7313   Pave  None         3
# 35      36          60       RL        108.0    13418   Pave  None         3
# 45      46         120       RL         61.0     7658   Pave  None         3
# 47      48          20       FV         84.0    11096   Pave  None         3
# 53      54          20       RL         68.0    50271   Pave  None         2
# 62      63         120       RL         44.0     6442   Pave  None         2
# 64      65          60       RL          0.0     9375   Pave  None         3
# 65      66          60       RL         76.0     9591   Pave  None         3
# 67      68          20       RL         72.0    10665   Pave  None         2
# 69      70          50       RL         81.0    15593   Pave  None         3
# 70      71          20       RL         95.0    13651   Pave  None         2
# 82      83          20       RL         78.0    10206   Pave  None         3
# 85      86          60       RL        121.0    16059   Pave  None         3
# 94      95          60       RL         69.0     9337   Pave  None         2
# 96      97          20       RL         78.0    10264   Pave  None         2
# 100    101          20       RL          0.0    10603   Pave  None         2
# 105    106          60       FV         75.0     9375   Pave  None         3
# 114    115          70       RL         61.0     7259   Pave  None         2
# 118    119          60       RL         90.0    12376   Pave  None         3
# 130    131          60       RL         88.0    14200   Pave  None         3
# 131    132          60       RL          0.0    12224   Pave  None         2
# 133    134          20       RL          0.0     6853   Pave  None         2
# ...    ...         ...      ...          ...      ...    ...   ...       ...
# 1328  1329          50       RM         60.0    10440   Pave  Grvl         3
# 1330  1331          20       RL         85.0    10000   Pave  None         3
# 1342  1343          60       RL          0.0     9375   Pave  None         3
# 1346  1347          20       RL          0.0    20781   Pave  None         1
# 1348  1349          20       RL          0.0    16196   Pave  None         0
# 1353  1354          50       RL         56.0    14720   Pave  None         2
# 1354  1355          60       RL          0.0    10316   Pave  None         2
# 1359  1360          20       RL        129.0    16737   Pave  None         3
# 1361  1362          20       RL        124.0    16158   Pave  None         2
# 1365  1366          60       FV          0.0     7500   Pave  None         3
# 1369  1370          20       RL         48.0    10635   Pave  None         1
# 1372  1373          60       RL         75.0     9750   Pave  None         3
# 1373  1374          20       RL          0.0    11400   Pave  None         3
# 1374  1375          60       FV         85.0    10625   Pave  None         3
# 1381  1382          20       RL          0.0    12925   Pave  None         2
# 1386  1387          60       RL         80.0    16692   Pave  None         2
# 1388  1389          20       RL         42.0    14892   Pave  None         2
# 1390  1391          20       RL         70.0     9100   Pave  None         3
# 1395  1396          60       RL         88.0    12665   Pave  None         2
# 1403  1404          20       RL         49.0    15256   Pave  None         2
# 1409  1410          60       RL         46.0    20544   Pave  None         2
# 1410  1411          60       RL         79.0    12420   Pave  None         3
# 1414  1415          50       RL         64.0    13053   Pave  Pave         3
# 1417  1418          60       RL          0.0    16545   Pave  None         2
# 1419  1420          20       RL          0.0    16381   Pave  None         2
# 1426  1427          60       RL         81.0    10944   Pave  None         2
# 1442  1443          60       FV         85.0    11003   Pave  None         3
# 1447  1448          60       RL         80.0    10000   Pave  None         3
# 1456  1457          20       RL         85.0    13175   Pave  None         3
# 1457  1458          70       RL         66.0     9042   Pave  None         3
#
#      LandContour  Utilities    ...     PoolArea  PoolQC  Fence  MiscFeature  \
# 0            Lvl          3    ...            0       0   None         None
# 2            Lvl          3    ...            0       0   None         None
# 4            Lvl          3    ...            0       0   None         None
# 6            Lvl          3    ...            0       0   None         None
# 22           Lvl          3    ...            0       0   None         None
# 25           Lvl          3    ...            0       0   None         None
# 27           Lvl          3    ...            0       0   None         None
# 28           Lvl          3    ...            0       0   None         None
# 34           Lvl          3    ...            0       0   None         None
# 35           Lvl          3    ...            0       0   None         None
# 45           Lvl          3    ...            0       0   None         None
# 47           Lvl          3    ...            0       0   None         None
# 53           Low          3    ...            0       0   None         None
# 62           Lvl          3    ...            0       0   None         None
# 64           Lvl          3    ...            0       0  GdPrv         None
# 65           Lvl          3    ...            0       0   None         None
# 67           Lvl          3    ...            0       0   None         None
# 69           Lvl          3    ...            0       0   None         None
# 70           Lvl          3    ...            0       0   None         None
# 82           Lvl          3    ...            0       0   None         None
# 85           Lvl          3    ...            0       0   None         None
# 94           Lvl          3    ...            0       0   None         None
# 96           Lvl          3    ...            0       0   None         None
# 100          Lvl          3    ...            0       0   None         None
# 105          Lvl          3    ...            0       0   None         None
# 114          Lvl          3    ...            0       0  MnPrv         None
# 118          Lvl          3    ...            0       0   None         None
# 130          Lvl          3    ...            0       0  GdPrv         None
# 131          Lvl          3    ...            0       0   None         None
# 133          Lvl          3    ...            0       0   None         None
# ...          ...        ...    ...          ...     ...    ...          ...
# 1328         Lvl          3    ...            0       0  MnPrv         Shed
# 1330         Lvl          3    ...            0       0   None         None
# 1342         Lvl          3    ...            0       0   None         None
# 1346         Lvl          3    ...            0       0   None         None
# 1348         Low          3    ...            0       0   None         None
# 1353         Lvl          3    ...            0       0   None         None
# 1354         Lvl          3    ...            0       0   None         None
# 1359         Lvl          3    ...            0       0   None         None
# 1361         Low          3    ...            0       0   None         None
# 1365         Lvl          3    ...            0       0   None         None
# 1369         Lvl          3    ...            0       0   None         None
# 1372         Lvl          3    ...            0       0   None         None
# 1373         Lvl          3    ...            0       0   None         None
# 1374         Lvl          3    ...            0       0   None         None
# 1381         Lvl          3    ...            0       0   None         None
# 1386         Lvl          3    ...          519       2  MnPrv         TenC
# 1388         HLS          3    ...            0       0   None         None
# 1390         Lvl          3    ...            0       0   None         None
# 1395         Lvl          3    ...            0       0   None         None
# 1403         Lvl          3    ...            0       0   None         None
# 1409         Lvl          3    ...            0       0  MnPrv         None
# 1410         Lvl          3    ...            0       0   None         None
# 1414         Bnk          3    ...            0       0   None         None
# 1417         Lvl          3    ...            0       0   None         None
# 1419         Lvl          3    ...            0       0   None         None
# 1426         Lvl          3    ...            0       0   None         None
# 1442         Lvl          3    ...            0       0   None         None
# 1447         Lvl          3    ...            0       0   None         None
# 1456         Lvl          3    ...            0       0  MnPrv         None
# 1457         Lvl          3    ...            0       0  GdPrv         Shed
#
#       MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0           0      2   2008        WD         Normal     208500
# 2           0      9   2008        WD         Normal     223500
# 4           0     12   2008        WD         Normal     250000
# 6           0      8   2007        WD         Normal     307000
# 22          0      9   2008        WD         Normal     230000
# 25          0      7   2009        WD         Normal     256300
# 27          0      5   2010        WD         Normal     306000
# 28          0     12   2006        WD         Normal     207500
# 34          0      8   2007        WD         Normal     277500
# 35          0      9   2006        WD         Normal     309000
# 45          0      2   2010        WD         Normal     319900
# 47          0      7   2007        WD         Normal     249700
# 53          0     11   2006        WD         Normal     385000
# 62          0     10   2007        WD         Normal     202500
# 64          0      2   2009        WD         Normal     219500
# 65          0     10   2007        WD         Normal     317000
# 67          0      6   2007        WD         Normal     226000
# 69          0      7   2006        WD         Normal     225000
# 70          0      2   2007        WD         Normal     244000
# 82          0     10   2008        WD         Normal     245000
# 85          0      4   2006        WD         Normal     260000
# 94          0      5   2007        WD         Normal     204750
# 96          0      8   2006        WD         Normal     214000
# 100         0      2   2010        WD         Normal     205000
# 105         0      8   2008        WD         Normal     250000
# 114         0      7   2007        WD         Normal     259500
# 118         0      5   2010        WD         Normal     320000
# 130         0      5   2006        WD         Normal     226000
# 131         0      7   2009        WD         Normal     244000
# 133         0      6   2009        WD         Normal     220000
# ...       ...    ...    ...       ...            ...        ...
# 1328     1150      6   2008        WD         Normal     256000
# 1330        0     12   2007        WD         Normal     227000
# 1342        0      8   2007        WD         Normal     228500
# 1346        0      6   2006        WD         Normal     262500
# 1348        0      8   2007        WD         Normal     215000
# 1353        0      3   2010        WD         Normal     410000
# 1354        0      6   2008        WD         Normal     235000
# 1359        0      9   2006        WD         Normal     315000
# 1361        0      6   2009        WD         Normal     260000
# 1365        0      1   2010        WD         Normal     216000
# 1369        0      5   2010        WD         Normal     232000
# 1372        0      6   2006        WD         Normal     274300
# 1373        0      3   2007        WD         Normal     466500
# 1374        0      7   2008        WD         Normal     250000
# 1381        0      5   2008        WD         Normal     237500
# 1386     2000      7   2006        WD         Normal     250000
# 1388        0     10   2009        WD         Normal     377500
# 1390        0      9   2006        WD         Normal     235000
# 1395        0      2   2007        WD         Normal     281213
# 1403        0      8   2007        WD         Normal     282922
# 1409        0     11   2008        WD         Normal     215000
# 1410        0      6   2009        WD         Normal     230000
# 1414        0      6   2008        WD         Normal     207000
# 1417        0      5   2009        WD         Normal     340000
# 1419        0     12   2006        WD         Normal     223000
# 1426        0      8   2008        WD         Normal     271000
# 1442        0      4   2009        WD         Normal     310000
# 1447        0     12   2007        WD         Normal     240000
# 1456        0      2   2010        WD         Normal     210000
# 1457     2500      5   2010        WD         Normal     266500
#
# [315 rows x 81 columns]

# %% [markdown]
# POPULAR NEIGHBORHOODS IN AMES
#
# City Center
# 24th St / Grand Ave
# Woodland St / West St
# Grand Ave / 30th St
# Stange Rd / Pammel Ct
# E 13Th St / Duff Ave
# S Duff Ave / E Lincoln Way
# Iowa State U / N Hyland Ave
# S Duff Ave / Airport Rd
# Lincoln Way / 500th Ave

# %%
r_house_final.Neighborhood.unique()
# Out:
# array(['MeadowV', 'Somerst', 'Edwards', 'NPkVill', 'OldTown', 'BrDale',
#        'Blmngtn', 'NridgHt', 'Blueste', 'ClearCr', 'StoneBr', 'IDOTRR',
#        'Crawfor'], dtype=object)

# %%
house_fixed_col =  ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle',  'YearBuilt', 'YearRemodAdd',
       'RoofStyle',  'Exterior1st',  'MasVnrType',
       'MasVnrArea',  'Foundation', 'GarageCars',
         'TotalBsmtSF', 
       '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea',  
        'Functional',         
         'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']

# %%
r_house_fixed = r_house_final_lux[house_fixed_col]
r_house_fixed.head(5)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 0    1          60       RL         65.0     8450   Pave  None         3
# 2    3          60       RL         68.0    11250   Pave  None         2
# 4    5          60       RL         84.0    14260   Pave  None         2
# 6    7          20       RL         75.0    10084   Pave  None         3
# 22  23          20       RL         75.0     9742   Pave  None         3
#
#    LandContour LotConfig    ...     1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0          Lvl    Inside    ...          856       854             0
# 2          Lvl    Inside    ...          920       866             0
# 4          Lvl       FR2    ...         1145      1053             0
# 6          Lvl    Inside    ...         1694         0             0
# 22         Lvl    Inside    ...         1795         0             0
#
#     GrLivArea Functional MoSold  YrSold  SaleType SaleCondition SalePrice
# 0        1710          7      2    2008        WD        Normal    208500
# 2        1786          7      9    2008        WD        Normal    223500
# 4        2198          7     12    2008        WD        Normal    250000
# 6        1694          7      8    2007        WD        Normal    307000
# 22       1795          7      9    2008        WD        Normal    230000
#
# [5 rows x 35 columns]

# %%
### feature selection..
numeric_fixed_lux = r_house_fixed.select_dtypes(include=[np.number])
numeric_fixed_lux.head(5)
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  Neighborhood  \
# 0    1          60         65.0     8450         3          2           5.0
# 2    3          60         68.0    11250         2          2           5.0
# 4    5          60         84.0    14260         2          2          10.0
# 6    7          20         75.0    10084         3          2          10.0
# 22  23          20         75.0     9742         3          2           5.0
#
#     Condition1  Condition2  YearBuilt    ...      GarageCars  TotalBsmtSF  \
# 0            5           5       2003    ...               2          856
# 2            5           5       2001    ...               2          920
# 4            5           5       2000    ...               3         1145
# 6            5           5       2004    ...               2         1686
# 22           5           5       2002    ...               2         1777
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  Functional  MoSold  YrSold  \
# 0        856       854             0       1710           7       2    2008
# 2        920       866             0       1786           7       9    2008
# 4       1145      1053             0       2198           7      12    2008
# 6       1694         0             0       1694           7       8    2007
# 22      1795         0             0       1795           7       9    2008
#
#     SalePrice
# 0      208500
# 2      223500
# 4      250000
# 6      307000
# 22     230000
#
# [5 rows x 22 columns]

# %%
r_house_train_lux = numeric_fixed[numeric_fixed['YrSold'] < 2010]

r_house_test_lux = numeric_fixed[numeric_fixed['YrSold'] == 2010]

# %%
r_house_test_lux.shape
# Out:
# (46, 22)

# %%
r_house_train_lux.shape
# Out:
# (269, 22)

# %%
#r_house_train_final = r_house_train.fillna(0)
r_house_train_final_lux = r_house_train_lux

# %%
X_train = r_house_train_final_lux.drop(['SalePrice'],axis =1)

y_train = np.log(r_house_train_lux.SalePrice.values)

# %%
#temp = np.log(r_house_train['SalePrice'])
y_train.shape = (269,1)
y_train
# Out:
# array([[12.24769432],
#        [12.31716669],
#        [12.4292162 ],
#        [12.63460303],
#        [12.34583459],
#        [12.45410391],
#        [12.24288662],
#        [12.53357621],
#        [12.64109656],
#        [12.42801548],
#        [12.86099861],
#        [12.21849517],
#        [12.29910751],
#        [12.66665705],
#        [12.32829028],
#        [12.32385568],
#        [12.4049235 ],
#        [12.40901349],
#        [12.46843691],
#        [12.229545  ],
#        [12.27373129],
#        [12.4292162 ],
#        [12.46651198],
#        [12.32829028],
#        [12.4049235 ],
#        [12.30138283],
#        [12.34583459],
#        [12.35233515],
#        [12.46843691],
#        [12.22587527],
#        [12.36734079],
#        [12.92999148],
#        [12.33710091],
#        [12.38421883],
#        [12.40081672],
#        [12.25961341],
#        [12.20657252],
#        [13.07107008],
#        [12.56374709],
#        [12.66032792],
#        [12.52416267],
#        [12.53177279],
#        [12.25486281],
#        [12.64915462],
#        [12.86424011],
#        [12.90669184],
#        [12.39462475],
#        [12.53177279],
#        [12.34583459],
#        [12.24288662],
#        [12.35233515],
#        [12.39462475],
#        [12.23076526],
#        [12.33929149],
#        [12.24288662],
#        [12.36734079],
#        [12.38421883],
#        [12.49500394],
#        [12.23076526],
#        [12.59473064],
#        [12.63101353],
#        [12.32385568],
#        [12.79385931],
#        [12.8346813 ],
#        [12.46843691],
#        [12.50617724],
#        [12.46843691],
#        [12.77705219],
#        [12.61486554],
#        [12.68849879],
#        [12.27606502],
#        [12.55672952],
#        [12.24047407],
#        [12.34125892],
#        [12.8411298 ],
#        [12.27373129],
#        [12.21849517],
#        [12.49125159],
#        [12.54254488],
#        [12.29910751],
#        [12.7367009 ],
#        [12.27139211],
#        [12.3883942 ],
#        [12.27839331],
#        [12.39255221],
#        [12.41105223],
#        [12.33710091],
#        [12.38421883],
#        [12.27839331],
#        [12.66032792],
#        [12.52452638],
#        [12.26434155],
#        [13.22672339],
#        [12.25486281],
#        [12.54254488],
#        [12.22587527],
#        [12.25486281],
#        [12.45293272],
#        [12.4292162 ],
#        [12.43320822],
#        [12.24961095],
#        [12.84792653],
#        [12.60148742],
#        [12.66032792],
#        [12.46843691],
#        [12.52197768],
#        [13.0530133 ],
#        [12.4292162 ],
#        [12.3779229 ],
#        [12.4292162 ],
#        [12.84132585],
#        [12.36734079],
#        [12.54686767],
#        [12.55292652],
#        [12.27839331],
#        [12.34583459],
#        [12.24047407],
#        [12.7367009 ],
#        [12.31492705],
#        [12.5098741 ],
#        [12.64432758],
#        [12.3883942 ]])

# %%
X_train.shape
# Out:
# (269, 21)

# %%
## linear regression for fixed
##instantiate the model.
lr = linear_model.LinearRegression(normalize = True)

#  Model fitting

model = lr.fit(X_train, y_train)

# %%
###Doing all data wrangling for X_test, y_test as for train

# %%
#r_house_test_final = r_house_test.fillna(0)
r_house_test_final_lux = r_house_test_lux

# %%
X_test = r_house_test_final_lux.drop(['SalePrice'],axis =1)

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[12.53993893],
#        [12.53347514],
#        [12.35856279],
#        [12.82379641],
#        [12.34921657],
#        [12.36039645],
#        [12.20540301],
#        [12.29923865],
#        [12.37033641],
#        [12.39052581],
#        [12.6020558 ],
#        [12.35074727],
#        [12.59977503],
#        [12.33481297],
#        [12.34363996],
#        [12.39075552],
#        [12.38066306],
#        [12.36585548],
#        [12.38832002],
#        [12.3185049 ],
#        [12.422899  ],
#        [12.43463015],
#        [12.23595344],
#        [12.96911722],
#        [12.38239657],
#        [12.42966114],
#        [12.32067194],
#        [12.35858347],
#        [12.23573143],
#        [12.20716979],
#        [12.30065075],
#        [12.18708111],
#        [12.31205494],
#        [12.52899317],
#        [12.61945187],
#        [12.51501221],
#        [12.47211855],
#        [12.67255833],
#        [12.35759831],
#        [12.4606663 ],
#        [12.69207511],
#        [12.96931298],
#        [12.22366864],
#        [12.425501  ],
#        [12.41878682],
#        [12.37450993]])

# %%
y_test = np.log(r_house_test_final_lux.SalePrice.values)
y_test
# Out:
# array([12.63134038, 12.67576373, 12.23076526, 12.67607627, 12.31268238,
#        12.44862659, 12.27839331, 12.28534583, 12.47800636, 12.23076526,
#        12.5776362 , 12.21106019, 12.39669301, 12.22046853, 12.26434155,
#        12.57418197, 12.51355735, 12.27373129, 12.30591798, 12.26904744,
#        12.37370349, 12.46997419, 12.27932311, 13.19561384, 12.35879373,
#        12.32341114, 12.37581542, 12.37158708, 12.20856953, 12.40656151,
#        12.27792808, 12.23563145, 12.27139211, 12.70076889, 12.69158046,
#        12.41044104, 12.4049235 , 12.84397135, 12.46843691, 12.72188581,
#        12.71640215, 12.92391244, 12.28303369, 12.35449265, 12.25486281,
#        12.49312952])

# %%
# ---- Evaluate Model performance and visualize results
# r-squared value is a measure of how close the data are to the fitted regression line
# a higher r-squared value means a better fit(very close to value 1)
print("R^2 is: \n", model.score(X_test, y_test))


print('RMSE is: ')
mean_squared_error(y_test, predictions)
# Out:
# R^2 is:
#  0.7144934915691339
# RMSE is:
# 0.012987085750250493

# %%
actual_values = y_test
  
            
plt.scatter(np.exp(predictions), np.exp(actual_values), alpha=.75, color='b')  # alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %%
print(np.exp(predictions))
print('/n')
print(np.exp(actual_values))
# Out:
# [[279271.28418365]
#  [277471.95371441]
#  [232946.19753883]
#  [370940.29770799]
#  [230779.17350358]
#  [233373.73321104]
#  [199866.11799935]
#  [219528.78784836]
#  [235705.02575341]
#  [240512.13103341]
#  [297168.85625379]
#  [231132.69711241]
#  [296491.85473885]
#  [227478.94664175]
#  [229495.79004404]
#  [240567.38666959]
#  [238151.68094325]
#  [234651.21126699]
#  [239982.19757063]
#  [223799.29000703]
#  [248425.67959689]
#  [251357.16002227]
#  [206066.3401486 ]
#  [428959.25654969]
#  [238564.87710309]
#  [250111.26115522]
#  [224284.7983739 ]
#  [232951.01370645]
#  [206020.59791508]
#  [200219.549723  ]
#  [219839.00257235]
#  [196237.53352404]
#  [222360.43855754]
#  [276231.1143864 ]
#  [302383.65361342]
#  [272396.01152932]
#  [260958.99154179]
#  [318876.2354332 ]
#  [232721.63224462]
#  [257987.47040733]
#  [325160.80028885]
#  [429043.23602787]
#  [203550.34290303]
#  [249072.92305007]
#  [247406.20398036]
#  [236690.80023448]]
# /n
# [306000. 319900. 205000. 320000. 222500. 254900. 215000. 216500. 262500.
#  205000. 290000. 201000. 242000. 202900. 212000. 289000. 272000. 214000.
#  221000. 213000. 236500. 260400. 215200. 538000. 233000. 224900. 237000.
#  236000. 200500. 244400. 214900. 206000. 213500. 328000. 325000. 245350.
#  244000. 378500. 260000. 335000. 333168. 410000. 216000. 232000. 210000.
#  266500.]

# %%
# Appending the predicted values to the  housing dataframe to do DF calcs


#Add predicted values to fixed_char_ DF
Fixed_Predictions = model.predict(X_train)

r_house_train_final_lux['FixedPredicted'] = np.exp(Fixed_Predictions)
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
Fixed_Predictions
# Out:
# array([[12.2623353 ],
#        [12.32136562],
#        [12.58411282],
#        [12.43533434],
#        [12.46484931],
#        [12.53280256],
#        [12.25692013],
#        [12.45220041],
#        [12.61055556],
#        [12.49787043],
#        [12.52926259],
#        [12.38733985],
#        [12.38328109],
#        [12.63586441],
#        [12.33015265],
#        [12.3256485 ],
#        [12.64111401],
#        [12.50951943],
#        [12.506497  ],
#        [12.2643586 ],
#        [12.37421115],
#        [12.44827533],
#        [12.43540637],
#        [12.30479144],
#        [12.36702989],
#        [12.25022252],
#        [12.45912395],
#        [12.28731425],
#        [12.40583148],
#        [12.33212916],
#        [12.16396418],
#        [12.79357356],
#        [12.39071068],
#        [12.35301092],
#        [12.43677377],
#        [12.41313161],
#        [12.01683612],
#        [12.86263943],
#        [12.43198023],
#        [12.48022015],
#        [12.52474355],
#        [12.44431245],
#        [12.30566263],
#        [12.34250359],
#        [12.88143055],
#        [12.78128024],
#        [12.44093881],
#        [12.7154562 ],
#        [12.42788822],
#        [12.28870212],
#        [12.30504859],
#        [12.34741384],
#        [12.24112296],
#        [12.31133264],
#        [12.33652074],
#        [12.35720523],
#        [12.48350857],
#        [12.57150323],
#        [12.26607242],
#        [12.11796742],
#        [12.47174367],
#        [12.58422673],
#        [12.31047294],
#        [12.33459656],
#        [12.38787174],
#        [12.27324668],
#        [12.29454981],
#        [12.36081509],
#        [12.3292653 ],
#        [12.36502079],
#        [13.12804058],
#        [12.45746792],
#        [12.29254507],
#        [12.72400608],
#        [12.50397185],
#        [12.44961336],
#        [12.38866129],
#        [12.70917206],
#        [12.44042069],
#        [12.36207208],
#        [12.29974489],
#        [12.11585973],
#        [12.43740656],
#        [12.57765955],
#        [12.85980617],
#        [12.3735523 ],
#        [12.35890121],
#        [12.45198779],
#        [12.3661709 ],
#        [12.63048455],
#        [12.48729575],
#        [12.46612832],
#        [12.62939535],
#        [12.27949144],
#        [12.50005459],
#        [12.56115825],
#        [12.39239358],
#        [12.51828835],
#        [12.45154533],
#        [12.50361928],
#        [12.35196785],
#        [12.40808942],
#        [12.6506341 ],
#        [12.43916656],
#        [12.37819228],
#        [12.93883947],
#        [12.46359727],
#        [12.34687698],
#        [12.59372742],
#        [12.56056524],
#        [12.34234416],
#        [12.62236444],
#        [12.46577686],
#        [12.36465994],
#        [12.30093803],
#        [12.26581898],
#        [12.66836698],
#        [12.4139232 ],
#        [12.47090147],
#        [12.48932198],
#        [12.44754244]])

# %%
# Residuals equals the difference between Y-True and Y-Pred
r_house_train_final_lux['Residuals'] = abs(r_house_train_final_lux['SalePrice']- r_house_train_final_lux['FixedPredicted'])
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#r_house_train_final.head(10)
#r_house_train_final.drop('Predicted', axis = 1, inplace = True)

# %%
r_house_train_final_lux
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  \
# 0        1          60         65.0     8450         3          2
# 2        3          60         68.0    11250         2          2
# 4        5          60         84.0    14260         2          2
# 6        7          20         75.0    10084         3          2
# 22      23          20         75.0     9742         3          2
# 25      26          20        110.0    14230         3          2
# 28      29          20         47.0    16321         2          2
# 34      35         120         60.0     7313         3          2
# 35      36          60        108.0    13418         3          2
# 47      48          20         84.0    11096         3          2
# 53      54          20         68.0    50271         2          2
# 62      63         120         44.0     6442         2          2
# 64      65          60          0.0     9375         3          2
# 65      66          60         76.0     9591         3          2
# 67      68          20         72.0    10665         2          2
# 69      70          50         81.0    15593         3          2
# 70      71          20         95.0    13651         2          2
# 82      83          20         78.0    10206         3          2
# 85      86          60        121.0    16059         3          2
# 94      95          60         69.0     9337         2          2
# 96      97          20         78.0    10264         2          2
# 105    106          60         75.0     9375         3          2
# 114    115          70         61.0     7259         2          1
# 130    131          60         88.0    14200         3          2
# 131    132          60          0.0    12224         2          2
# 133    134          20          0.0     6853         2          2
# 138    139          60         73.0     9066         2          2
# 139    140          60         65.0    15426         2          2
# 141    142          20         78.0    11645         3          2
# 143    144          20         78.0    10335         2          2
# ...    ...         ...          ...      ...       ...        ...
# 1305  1306          20        108.0    13173         2          2
# 1312  1313          60          0.0     9572         2          2
# 1315  1316          60         85.0    11075         3          2
# 1316  1317          20         61.0    10226         2          2
# 1318  1319          20          0.0    14781         1          2
#
#       SalePrice  FixedPredicted      Residuals
# 0        208500   211575.099892    3075.099892
# 2        223500   224440.433252     940.433252
# 4        250000   291884.315331   41884.315331
# 6        307000   251534.223784   55465.776216
# 22       230000   259068.894706   29068.894706
# 25       256300   277285.393369   20985.393369
# 28       207500   210432.482714    2932.482714
# 34       277500   255812.597640   21687.402360
# 35       309000   299705.487711    9294.512289
# 47       249700   267766.450266   18066.450266
# 53       385000   276305.548998  108694.451002
# 62       202500   239747.089914   37247.089914
# 64       219500   238775.984544   19275.984544
# 65       317000   307387.488077    9612.511923
# 67       226000   226421.287807     421.287807
# 69       225000   225403.745469     403.745469
# 70       244000   309005.391839   65005.391839
# 82       245000   270903.902263   25903.902263
# 85       260000   270086.348409   10086.348409
# 94       204750   212003.613794    7253.613794
# 96       214000   236620.092176   22620.092176
# 105      250000   254810.479214    4810.479214
# 114      259500   251552.342103    7947.657897
# 130      226000   220751.175653    5248.824347
# 131      244000   234926.947951    9073.052049
# 133      220000   209027.797549   10972.202451
# 138      230000   257589.870383   27589.870383
# 139      231500   216926.583079   14573.416921
# 141      260000   244221.645754   15778.354246
# 143      204000   226869.255419   22869.255419
# ...         ...             ...            ...
# 1305     325000   259400.459412   65599.540588
# 1312     302000   305405.399401    3405.399401
# 1315     206900   215236.227716    8336.227716
# 1316     295493   268351.934547   27141.065453
# 1318     275000   285260.550333   10260.550333
# 1328     256000   240961.773775   15038.226225
# 1330     227000   273289.881708   46289.881708
# 1342     228500   255645.073291   27145.073291
# 1346     262500   269310.234526    6810.234526
# 1348     215000   231414.984768   16414.984768
# 1354     235000   244773.707655    9773.707655
# 1359     315000   311961.199789    3038.800211
# 1361     260000   252500.007424    7499.992576
# 1372     274300   237563.986261   36736.013739
# 1373     466500   416165.986852   50334.013148
# 1374     250000   258744.732458    8744.732458
# 1381     237500   230239.876094    7260.123906
# 1386     250000   294704.200120   44704.200120
# 1388     377500   285091.436508   92408.563492
# 1390     235000   229198.601934    5801.398066
# 1395     281213   303265.650781   22052.650781
# 1403     282922   259309.306606   23612.693394
# 1409     215000   234370.842531   19370.842531
# 1410     230000   219902.167231   10097.832769
# 1414     207000   212313.445926    5313.445926
# 1417     340000   317542.509353   22457.490647
# 1419     223000   246205.837754   23205.837754
# 1426     271000   260641.575697   10358.424303
# 1442     310000   265487.219806   44512.780194
# 1447     240000   254623.800240   14623.800240
#
# [269 rows x 24 columns]

# %%
r_house_train_final_lux.shape
# Out:
# (269, 24)

# %%
r_house_test_final_lux['FixedPredicted'] = np.exp(predictions)
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
r_house_test_final_lux['Residuals'] = abs(r_house_test_final_lux['SalePrice']-r_house_test_final_lux['FixedPredicted'])
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#r_house_test_final.drop('Predicted', axis = 1, inplace = True)

# %%
r_house_test_final_lux.shape
# Out:
# (46, 24)

# %% [markdown]
# Neighborhood: Physical locations within Ames city limits
#                                                   Add flood plain overlay
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker

# %%
### concat both dataframes together  ...new Df = df1.append(df2)
r_house_fixed_combined_lux =    r_house_train_final_lux.append(r_house_test_final_lux)

# %%
##do standardisation
#scaler = StandardScaler.fit(X_train)
#standardised_X = scaler.transform(X_train)
#standardised_X_test = scaler.transform(X_test)
#scaler = StandardScaler.fit(X)
#standardised_X = scaler.transform(X)
#standardised_X_test = scaler.transform(X_test)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Determine any value of *changeable* property characteristics unexplained by the *fixed* ones.
#
# ---
#
# Now that you have a model that estimates the price of a house based on its static characteristics, we can move forward with part 2 and 3 of the plan: what are the costs/benefits of quality, condition, and renovations?
#
# There are two specific requirements for these estimates:
# 1. The estimates of effects must be in terms of dollars added or subtracted from the house value.
# 2. The effects must be on the variance in price remaining from the first model.
#
# The residuals from the first model (training and testing) represent the variance in price unexplained by the fixed characteristics. Of that variance in price remaining, how much of it can be explained by the easy-to-change aspects of the property?
#
# ---
#
# **Your goals:**
# 1. Evaluate the effect in dollars of the renovate-able features.
# - How would your company use this second model and its coefficients to determine whether they should buy a property or not? Explain how the company can use the two models you have built to determine if they can make money.
# - Investigate how much of the variance in price remaining is explained by these features.
# - Do you trust your model? Should it be used to evaluate which properties to buy and fix up?

# %%
#Some examples of things that ARE renovate-able:
#Roof and exterior features
#"Quality" metrics, such as kitchen quality
#"Condition" metrics, such as condition of garage
#Heating and electrical components
#and generally anything you deem can be modified without having to undergo major construction on the house.


house_var_col = ['Id', 'Neighborhood',  'Utilities', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 
'RoofStyle', 'RoofMatl',  'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',  'BsmtQual',
'BsmtCond', 'BsmtFinType2', 'BsmtUnfSF',  'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', 
        'BsmtHalfBath', 
       'HalfBath',   'KitchenQual',
       'TotRmsAbvGrd', 'Functional',  'FireplaceQu', 
       'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']

# %%
#r_house_final

# %%
r_house_VarFeat = r_house_final_lux[house_var_col]

# %%
r_house_VarFeat.shape
# Out:
# (315, 46)

# %%
r_house_VarFeat.head(4)
# Out:
#    Id  Neighborhood  Utilities  OverallQual  OverallCond  YearBuilt  \
# 0   1           5.0          3            7            5       2003
# 2   3           5.0          3            7            5       2001
# 4   5          10.0          3            8            5       2000
# 6   7          10.0          3            8            5       2004
#
#    YearRemodAdd RoofStyle RoofMatl Exterior2nd    ...     PoolArea  PoolQC  \
# 0          2003     Gable  CompShg     VinylSd    ...            0       0
# 2          2002     Gable  CompShg     VinylSd    ...            0       0
# 4          2000     Gable  CompShg     VinylSd    ...            0       0
# 6          2005     Gable  CompShg     VinylSd    ...            0       0
#
#    Fence  MiscFeature  MiscVal  MoSold YrSold  SaleType SaleCondition  \
# 0   None         None        0       2   2008        WD        Normal
# 2   None         None        0       9   2008        WD        Normal
# 4   None         None        0      12   2008        WD        Normal
# 6   None         None        0       8   2007        WD        Normal
#
#    SalePrice
# 0     208500
# 2     223500
# 4     250000
# 6     307000
#
# [4 rows x 46 columns]

# %%
r_house_fixed_combined_lux.shape
# Out:
# (315, 24)

# %%
r_house_fixed_combined_lux.head(3)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  LotShape  LandSlope  Neighborhood  \
# 0   1          60         65.0     8450         3          2           5.0
# 2   3          60         68.0    11250         2          2           5.0
# 4   5          60         84.0    14260         2          2          10.0
#
#    Condition1  Condition2  YearBuilt      ...       1stFlrSF  2ndFlrSF  \
# 0           5           5       2003      ...            856       854
# 2           5           5       2001      ...            920       866
# 4           5           5       2000      ...           1145      1053
#
#    LowQualFinSF  GrLivArea  Functional  MoSold  YrSold  SalePrice  \
# 0             0       1710           7       2    2008     208500
# 2             0       1786           7       9    2008     223500
# 4             0       2198           7      12    2008     250000
#
#    FixedPredicted     Residuals
# 0   211575.099892   3075.099892
# 2   224440.433252    940.433252
# 4   291884.315331  41884.315331
#
# [3 rows x 24 columns]

# %%
temp_df = r_house_fixed_combined_lux[['Id' , 'FixedPredicted']]

# %%
temp_df.head(3)
# Out:
#    Id  FixedPredicted
# 0   1   211575.099892
# 2   3   224440.433252
# 4   5   291884.315331

# %%
##pd.merge(df1, df2, on='employee')

# %%
 FDF = pd.merge(r_house_VarFeat, temp_df, on='Id')

# %%
FDF.shape
# Out:
# (315, 47)

# %%
FDF['Residuals'] = abs( FDF['SalePrice'] - FDF['FixedPredicted'] )

# %%
FDF.shape
# Out:
# (315, 48)

# %%
FDF.columns
# Out:
# Index(['Id', 'Neighborhood', 'Utilities', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'BsmtFinType2', 'BsmtUnfSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'BsmtHalfBath', 'HalfBath', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'FireplaceQu', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice',
#        'FixedPredicted', 'Residuals'],
#       dtype='object')

# %%
FDF_num =     FDF.select_dtypes(include=[np.number])

# %%
### where renovations were done
FDF_REMOD = FDF_num[FDF['YearBuilt'] != FDF['YearRemodAdd']]

# %%
#  prepare Train and test for residuals
#first prepare train  
##  REMOVE houses where remodel add and year built are same
#  

RHV_T1  = FDF_REMOD[FDF_REMOD['YrSold'] < 2010]
#RHV_train = RHV_T1.dropna(0)

# %%
RHV_T1.shape
# Out:
# (134, 36)

# %%
RHV_train = RHV_T1

# %%
RHV_train
# Out:
#        Id  Neighborhood  Utilities  OverallQual  OverallCond  YearBuilt  \
# 1       3           5.0          3            7            5       2001
# 3       7          10.0          3            8            5       2004
# 7      29          10.0          3            5            6       1957
# 9      36          10.0          3            8            5       2004
# 12     54           2.5          3            9            5       1981
# 14     65           5.0          3            7            5       1997
# 15     66          10.0          3            8            5       2004
# 20     86          10.0          3            8            5       1991
# 24    106          10.0          3            8            5       2003
# 25    115          10.0          3            6            8       1945
# 29    134          10.0          3            8            5       2001
# 30    139           5.0          3            8            5       1999
# 35    154          10.0          3            6            7       1960
# 37    162          10.0          3            9            5       2003
# 41    176          10.0          3            6            7       1950
# 42    177          10.0          3            6            5       1988
# 43    182          10.0          3            7            6       1920
# 44    186          10.0          3           10            9       1892
# 45    190          10.0          3            8            5       2001
# 46    191          10.0          3            8            8       1932
# 47    200          10.0          3            8            5       2004
# 48    209          10.0          3            7            5       1988
# 265            0         0       0        0       6    2006     230000
# 267            0         0       0        0       7    2007     294000
# 270            0         0       0        0       5    2008     381000
# 278            0         0       0        0      11    2009     325000
# 284            0         0       0        0       8    2006     275000
# 285          480         0       0     1150       6    2008     256000
# 288            0         0       0        0       6    2006     262500
# 292            0         0       0        0       9    2006     315000
# 297            0         0       0        0       3    2007     466500
# 301            0         0       0        0      10    2009     377500
# 303            0         0       0        0       2    2007     281213
# 305            0         0       0        0      11    2008     215000
# 307          220         0       0        0       6    2008     207000
# 312            0         0       0        0      12    2007     240000
#
#      FixedPredicted      Residuals
# 1     224440.433252     940.433252
# 3     251534.223784   55465.776216
# 7     210432.482714    2932.482714
# 9     299705.487711    9294.512289
# 12    276305.548998  108694.451002
# 14    238775.984544   19275.984544
# 15    307387.488077    9612.511923
# 20    270086.348409   10086.348409
# 24    254810.479214    4810.479214
# 25    251552.342103    7947.657897
# 29    209027.797549   10972.202451
# 30    257589.870383   27589.870383
# 35    191753.156510   43246.843490
# 37    359897.143340   52602.856660
# 41    251896.550244    8896.550244
# 42    246011.020442   35011.020442
# 43    165518.147260   34581.852740
# 44    385632.234346   89367.765654
# 45    250691.963257   35308.036743
# 46    263081.762622   51918.237378
# 47    275059.730358     159.730358
# 48    253802.693284   23197.306716
# 50    229235.144264   82264.855736
# 52    355499.896580   47500.103420
# 57    332852.989062   55852.989062
# 61    230363.514791   11136.485209
# 63    207134.364061    2134.364061
# 66    227867.760831   20367.760831
# 67    232630.173319    2369.826681
# 68    263948.309557   24948.309557
# ..              ...            ...
# 242   260861.181963    8861.181963
# 244   291917.564877   11917.564877
# 246   227429.722458   12429.722458
# 248   213896.317433   12096.317433
# 249   218501.860244     501.860244
# 250   233471.451768    3471.451768
# 251   226220.462129    2220.462129
# 253   234455.430145     544.569855
# 254   502846.671797  122153.328203
# 255   257163.647355   56663.647355
# 256   218064.260898   20935.739102
# 257   335711.043378   50711.043378
# 258   269405.200952   19405.200952
# 259   255151.651583    6848.348417
# 260   240064.108495   27064.108495
# 261   330767.853440   58867.853440
# 265   182747.323588   47252.676412
# 267   252055.998775   41944.001225
# 270   384541.183644    3541.183644
# 278   259400.459412   65599.540588
# 284   285260.550333   10260.550333
# 285   240961.773775   15038.226225
# 288   269310.234526    6810.234526
# 292   311961.199789    3038.800211
# 297   416165.986852   50334.013148
# 301   285091.436508   92408.563492
# 303   303265.650781   22052.650781
# 305   234370.842531   19370.842531
# 307   212313.445926    5313.445926
# 312   254623.800240   14623.800240
#
# [134 rows x 36 columns]

# %%
RHV_train.shape
# Out:
# (134, 36)

# %%
RHV_T2 = FDF_REMOD[FDF_REMOD['YrSold'] == 2010]
RHV_test = RHV_T2

# %%
RHV_test
## YearRemodAdd: Remodel date (same as construction date if no remodeling or add
# Out:
#        Id  Neighborhood  Utilities  OverallQual  OverallCond  YearBuilt  \
# 6      28          10.0          3            8            5       2007
# 23    101          10.0          3            6            7       1977
# 36    159          10.0          3            7            5       2004
#        5.31344593e+03, 1.46238002e+04])

# %%
X_train_var = RHV_train.drop(['Residuals'], axis =1)

# %%
#RHV_train

# %%
y_test_var = RHV_test.Residuals.values
y_test_var
# Out:
# array([26728.71581635, 27946.19753883, 21526.26678896, 35512.13103341,
#         7168.85625379, 54491.85473885, 48432.61333041, 33848.31905675,
#        10799.29000703, 11925.67959689,  3048.98629355, 44180.450277  ,
#         4939.00257235, 51768.8856136 , 22616.34638658, 59623.7645668 ,
#        77012.52959267, 19043.23602787, 37406.20398036, 29809.19976552])

# %%
X_test_var = RHV_test.drop(['Residuals'], axis =1)

# %%
X_train_var.shape
# Out:
# (134, 35)

# %%
X_test_var.shape
# Out:
# (20, 35)

# %%
y_test_var.shape = (20,1)

# %%
y_test_var.shape
# Out:
# (20, 1)

# %%
y_train_var.shape = (134,1)

# %%
y_train_var.shape
# Out:
# (134, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lrvar = linear_model.LinearRegression()


#  Model fitting
X = X_train_var
y = y_train_var

# %%
varmodel = lrvar.fit(X,y)

# %%
Var_predictions = varmodel.predict(X_test_var)

# %%
Var_predictions
# Out:
# array([[30468.74760041],
#        [ 6144.8525992 ],
#        [10872.70705576],
#        [-4098.87237094],
#        [17840.68084099],
#        [ 7555.94519226],
#        [30985.9618682 ],
#        [52074.78846511],
#        [ 1809.87161533],
#        [15672.2934141 ],
#        [ 8730.09635149],
#        [28246.95913235],
#        [-1872.30725716],
#        [29106.64012216],
#        [30271.4179959 ],
#        [43739.48242468],
#        [32591.41335461],
#        [45486.88266474],
#        [16424.6341138 ],
#        [35258.84734635]])

# %%
pred_temp_df = pd.DataFrame((abs(Var_predictions) * 5)/10)

# %%
pred_temp_df.values
# Out:
# array([[15234.37380021],
#        [ 3072.4262996 ],
#        [ 5436.35352788],
#        [ 2049.43618547],
#        [ 8920.34042049],
#        [ 3777.97259613],
#        [15492.9809341 ],
#        [26037.39423256],
#        [  904.93580766],
#        [ 7836.14670705],
#        [ 4365.04817574],
#        [14123.47956618],
#        [  936.15362858],
#        [14553.32006108],
#        [15135.70899795],
#        [21869.74121234],
#        [16295.70667731],
#        [22743.44133237],
#        [ 8212.3170569 ],
#        [17629.42367318]])

# %%
#RHV_test['Var_Predicted'] = pred_temp_df
# Out:
# /Users/pramodpaul/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#RHV_test
# Out:
#      Id  Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 15  386          3            8            5       2004          2005
# 29  604          3            7            5       2004          2005
#
#     MasVnrArea  ExterQual  ExterCond  BsmtQual      ...        ScreenPorch  \
# 15        16.0          4          3         4      ...                144
# 29         0.0          4          3         4      ...                  0
#
#     PoolArea  PoolQC  MiscVal  MoSold  YrSold  SalePrice  FixedPredicted  \
# 15         0       0        0       4    2010     192000   166809.335285
# 29         0       0        0       6    2010     151000   150569.237586
#
#        Residuals  Var_Predicted
# 15  25190.664715            NaN
# 29    430.762414            NaN
#
# [2 rows x 36 columns]

# %%
pred_temp_df
# Out:
#                0
# 0   15234.373800
# 1    3072.426300
# 2    5436.353528
# 3    2049.436185
# 4    8920.340420
# 5    3777.972596
# 6   15492.980934
# 7   26037.394233
# 8     904.935808
# 9    7836.146707
# 10   4365.048176
# 11  14123.479566
# 12    936.153629
# 13  14553.320061
# 14  15135.708998
# 15  21869.741212
# 16  16295.706677
# 17  22743.441332
# 18   8212.317057
# 19  17629.423673

# %%
#RHV_test['Depreciated_pred'] = 
VDV = pd.merge(RHV_test, temp_df, on='Id')

# %%
print(Var_predictions)
print('/n')
RHV_test.Residuals.values
# Out:
# [[30468.74760041]
#  [ 6144.8525992 ]
#  [10872.70705576]
#  [-4098.87237094]
#  [17840.68084099]
#  [ 7555.94519226]
#  [30985.9618682 ]
#  [52074.78846511]
#  [ 1809.87161533]
#  [15672.2934141 ]
#  [ 8730.09635149]
#  [28246.95913235]
#  [-1872.30725716]
#  [29106.64012216]
#  [30271.4179959 ]
#  [43739.48242468]
#  [32591.41335461]
#  [45486.88266474]
#  [16424.6341138 ]
#  [35258.84734635]]
# /n
# array([[26728.71581635],
#        [27946.19753883],
#        [21526.26678896],
#        [35512.13103341],
#        [ 7168.85625379],
#        [54491.85473885],
#        [48432.61333041],
#        [33848.31905675],
#        [10799.29000703],
#        [11925.67959689],
#        [ 3048.98629355],
#        [44180.450277  ],
#        [ 4939.00257235],
#        [51768.8856136 ],
#        [22616.34638658],
#        [59623.7645668 ],
#        [77012.52959267],
#        [19043.23602787],
#        [37406.20398036],
#        [29809.19976552]])

# %%
print("R^2 is: \n", varmodel.score(X_test_var, pred_temp_df.values))


print('RMSE is: ')
mean_squared_error(y_test_var, pred_temp_df.values)
# Out:
# R^2 is:
#  -2.2764137322016555
# RMSE is:
# 722671728.3187896

# %%
pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[np.mean])
# Out:
#                        mean                                               \
#                   SalePrice
# YrSold                 2006           2007           2008           2009
# Neighborhood
# 2.5           176457.142857  161159.375000  183446.153846  167860.461538
# 5.0           199545.357143  201579.367347  187344.565217  194906.661017
# 7.0           123466.666667  105850.000000   98000.000000   88400.000000
# 10.0          179689.585062  185905.530769  175798.539095  178254.298851
#
#
#
# YrSold                 2010
# Neighborhood
# 2.5           166950.000000
# 5.0           197952.631579
# 7.0            81333.333333
# 10.0          176986.530201

# %%
#plt.style.use('fivethirtyeight')
ax = pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[np.median]).plot(kind='bar', rot=65, figsize=(16,8), width=.8)
ax.set_xlabel('Neighborhood', fontsize=14)
ax.set_title('Sales price of Homes Sold by Year & neighborhood', fontsize=14)
ax.legend(labels=['2006','2007','2008','2009','2010']);

# %%
#plt.style.use('fivethirtyeight')
ax = pd.pivot_table(house, index=['Neighborhood'], values=['SalePrice'], columns = ['YrSold'], aggfunc=[len]).plot(kind='bar', rot=65, figsize=(16,8), width=.8)
ax.set_xlabel('Neighborhood', fontsize=14)
ax.set_title('Number of Homes Sold by Year', fontsize=14)
ax.legend(labels=['2006','2007','2008','2009','2010']);

# %%
house.MiscFeature.unique()
# Out:
# array(['None', 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
house[house.MiscFeature=='Othr'].MiscVal
# Out:
# 705    3500
# 873       0
# Name: MiscVal, dtype: int64

# %%
house.MiscVal.unique()
# Out:
# array([    0,   700,   350,   500,   400,   480,   450, 15500,  1200,
#          800,  2000,   600,  3500,  1300,    54,   620,   560,  1400,
#         8300,  1150,  2500])

# %%
house_var = house[house_var_col]
house_var.head(3)
# Out:
#    Id Neighborhood  Utilities  OverallQual  OverallCond  YearBuilt  \
# 0   1      CollgCr          3            7            5       2003
# 1   2      Veenker          3            6            8       1976
# 2   3      CollgCr          3            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior2nd    ...     PoolArea  PoolQC  \
# 0          2003     Gable  CompShg     VinylSd    ...            0       0
# 1          1976     Gable  CompShg     MetalSd    ...            0       0
# 2          2002     Gable  CompShg     VinylSd    ...            0       0
#
#    Fence  MiscFeature  MiscVal  MoSold YrSold  SaleType SaleCondition  \
# 0   None         None        0       2   2008        WD        Normal
# 1   None         None        0       5   2007        WD        Normal
# 2   None         None        0       9   2008        WD        Normal
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
#
# [3 rows x 46 columns]

# %% [markdown]
#  TO DO
#
#  remove abnormal sale =  SaleCondition = Abnormal
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %%
house_var_price_columns = ['YearBuilt','YearRemodAdd' ,'MoSold', 'YrSold','SaleType','SalePrice','SaleCondition']

# %%
house_var_price = house_var[house_var_price_columns]

# %%
house_var_price.YrSold.min()    ## 2006 -2010
# Out:
# 2006

# %%
house_var_price.YearBuilt.max()   #....1872 - 2010
# Out:
# 2010

# %%
house_var_price.YearBuilt.max()   #....1872 - 2010
# Out:
# 2010

# %%
house_var_price.YearRemodAdd.max()   # 1950 -2010
# Out:
# 2010

# %%
house_var_solver = house_var[house_var['YearBuilt'] !=  house_var['YearRemodAdd']]

# %%
house_var_solver.shape
# Out:
# (696, 46)

# %%
house_var_test = house_var[house_var['YrSold'] ==  house_var['YearRemodAdd']]

# %%
#house_var_test

# %%
house_var_train = house_var[house_var['YrSold'] == 2010]

# %%
house_var_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 16 to 1458
# Data columns (total 46 columns):
# Id               175 non-null int64
# Neighborhood     175 non-null object
# Utilities        175 non-null int64
# OverallQual      175 non-null int64
# OverallCond      175 non-null int64
# YearBuilt        175 non-null int64
# YearRemodAdd     175 non-null int64
# RoofStyle        175 non-null object
# RoofMatl         175 non-null object
# Exterior2nd      175 non-null object
# MasVnrType       175 non-null object
# MasVnrArea       175 non-null float64
# ExterQual        175 non-null int64
# ExterCond        175 non-null int64
# BsmtQual         175 non-null int64
# BsmtCond         175 non-null int64
# BsmtFinType2     175 non-null object
# BsmtUnfSF        175 non-null int64
# Heating          175 non-null object
# HeatingQC        175 non-null int64
# CentralAir       175 non-null int64
# Electrical       175 non-null object
# BsmtHalfBath     175 non-null int64
# HalfBath         175 non-null int64
# KitchenQual      175 non-null int64
# TotRmsAbvGrd     175 non-null int64
# Functional       175 non-null int64
# FireplaceQu      175 non-null int64
# GarageQual       175 non-null int64
# GarageCond       175 non-null int64
# PavedDrive       175 non-null object
# WoodDeckSF       175 non-null int64
# OpenPorchSF      175 non-null int64
# EnclosedPorch    175 non-null int64
# 3SsnPorch        175 non-null int64
# ScreenPorch      175 non-null int64
# PoolArea         175 non-null int64
# PoolQC           175 non-null int64
# Fence            175 non-null object
# MiscFeature      175 non-null object
# MiscVal          175 non-null int64
# MoSold           175 non-null int64
# YrSold           175 non-null int64
# SaleType         175 non-null object
# SaleCondition    175 non-null object
# SalePrice        175 non-null int64
# dtypes: float64(1), int64(32), object(13)
# memory usage: 64.3+ KB

# %%
##house_var_train

# %%
dum_MasVnrType = house_var_train[['MasVnrType']].copy()
dum_MasVnrType.head(10)
# Out:
#    MasVnrType
# 16    BrkFace
# 24       None
# 26       None
# 27      Stone
# 33       None
# 38       None
# 45    BrkFace
# 52       None
# 63       None
# 66    BrkFace

# %%
dum_Mas = pd.get_dummies(dum_MasVnrType)
dum_Mas.head()
# Out:
#     MasVnrType_BrkCmn  MasVnrType_BrkFace  MasVnrType_None  MasVnrType_Stone
# 16                  0                   1                0                 0
# 24                  0                   0                1                 0
# 26                  0                   0                1                 0
# 27                  0                   0                0                 1
# 33                  0                   0                1                 0

# %%
for col in dum_Mas.columns:
    print(col)
    print(dum_Mas[col].value_counts())
    print('\n')
# Out:
# MasVnrType_BrkCmn
# 0    174
# 1      1
# Name: MasVnrType_BrkCmn, dtype: int64
#
#
# MasVnrType_BrkFace
# 0    122
# 1     53
# Name: MasVnrType_BrkFace, dtype: int64
#
#
# MasVnrType_None
# 1    105
# 0     70
# Name: MasVnrType_None, dtype: int64
#
#
# MasVnrType_Stone
# 0    159
# 1     16
# Name: MasVnrType_Stone, dtype: int64

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. What property characteristics predict an "abnormal" sale?
#
# ---
#
# The `SaleCondition` feature indicates the circumstances of the house sale. From the data file, we can see that the possibilities are:
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# One of the executives at your company has an "in" with higher-ups at the major regional bank. His friends at the bank have made him a proposal: if he can reliably indicate what features, if any, predict "abnormal" sales (foreclosures, short sales, etc.), then in return the bank will give him first dibs on the pre-auction purchase of those properties (at a dirt-cheap price).
#
# He has tasked you with determining (and adequately validating) which features of a property predict this type of sale.
#
# ---
#
# **Your task:**
# 1. Determine which features predict the `Abnorml` category in the `SaleCondition` feature.
# - Justify your results.
#
# This is a challenging task that tests your ability to perform classification analysis in the face of severe class imbalance. You may find that simply running a classifier on the full dataset to predict the category ends up useless: when there is bad class imbalance classifiers often tend to simply guess the majority class.
#
# It is up to you to determine how you will tackle this problem. I recommend doing some research to find out how others have dealt with the problem in the past. Make sure to justify your solution. Don't worry about it being "the best" solution, but be rigorous.
#
# Be sure to indicate which features are predictive (if any) and whether they are positive or negative predictors of abnormal sales.

# %%
# A:

#Feature selection using SelectFromModel and LassoCV — scikit-learn 0.20.3 documentation#
#https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_boston.html
    #sphx-glr-auto-examples-feature-selection-plot-select-from-model-boston-py
